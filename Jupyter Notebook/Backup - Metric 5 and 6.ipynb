# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/Metric%205%20-%20Sheet2.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#   Project_Name Version Commit_ID  LOC\n  Bugs  Added+Changed  Code_Churned  \
# 0   Collection   3.2.1   0af3ae8  58646    41            613      0.010453
# 1   Collection   3.2.2   8e217b4  59597     9            951      0.015957
# 2   Collection       4   db18992  54993    74           4604      0.083720
# 3   Collection     4.1   cb15716  64783    28           9790      0.151120
# 4   Collection     4.2   483cbbb  66695    15           1912      0.028668
#
#    Defect_Density
# 0        0.699110
# 1        0.151014
# 2        1.345626
# 3        0.432212
# 4        0.224904

# %%
boxplot = df.boxplot(column=['Added+Changed', 'Code_Churned', 'Defect_Density'])

# %%
df.plot(x='Code_Churned', y='Defect_Density', style='o')

# %%
df.corr(method ='spearman')
# Out:
#                    LOC\n      Bugs  Added+Changed  Code_Churned  \
# LOC\n           1.000000 -0.138068      -0.013564     -0.314214
# Bugs           -0.138068  1.000000       0.252283      0.261304
# Added+Changed  -0.013564  0.252283       1.000000      0.942063
# Code_Churned   -0.314214  0.261304       0.942063      1.000000
# Defect_Density -0.651443  0.803616       0.161183      0.345960
#
#                 Defect_Density
# LOC\n                -0.651443
# Bugs                  0.803616
# Added+Changed         0.161183
# Code_Churned          0.345960
# Defect_Density        1.000000

# %%
df[['Code_Churned','Defect_Density']].corr(method ='spearman')
# Out:
#                 Code_Churned  Defect_Density
# Code_Churned         1.00000         0.34596
# Defect_Density       0.34596         1.00000
