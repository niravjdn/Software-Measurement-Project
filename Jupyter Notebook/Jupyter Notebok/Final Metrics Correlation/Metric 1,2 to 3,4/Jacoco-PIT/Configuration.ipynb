# %%
import pandas as pd
import scipy.stats  as stats

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/pit-jacoco/config-mu-st-branch.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df.plot(x='Mutation_Score', y='Statement_Percentage', style='o')

# %%
df_clean = df.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['Mutation_Score'])
# Out:
# SpearmanrResult(correlation=0.6840402618242469, pvalue=4.6771094040237014e-21)

# %%
df[['Mutation_Score','Statement_Percentage']].corr(method ='spearman')
# Out:
#                       Mutation_Score  Statement_Percentage
# Mutation_Score              1.000000              0.738824
# Statement_Percentage        0.738824              1.000000

# %%
df.plot(x='Mutation_Score', y='Branch_Percentage', style='o')

# %%
df_clean = df.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['Mutation_Score'])
# Out:
# SpearmanrResult(correlation=0.6424258348704701, pvalue=5.230892952419403e-18)

# %%
df[['Mutation_Score','Branch_Percentage']].corr(method ='spearman')
# Out:
#                    Mutation_Score  Branch_Percentage
# Mutation_Score           1.000000           0.642426
# Branch_Percentage        0.642426           1.000000
