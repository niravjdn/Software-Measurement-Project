# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/configuration/common-configuration-2.1.1.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                           GROUP                                      PACKAGE  \
# 0  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 1  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 2  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 3  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 4  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
#
#                                 CLASS  INSTRUCTION_MISSED  \
# 0              ConfigurationDynaClass                  36
# 1                  DefaultBeanFactory                   7
# 2  BeanHelper.BeanCreationContextImpl                   5
# 3         XMLBeanDeclaration.NodeData                   0
# 4                  XMLBeanDeclaration                  51
#
#    INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  \
# 0                  140              4              26            5
# 1                  258              3              27            0
# 2                   30              0               0            1
# 3                   89              0               2            0
# 4                  315              8              28           13
#
#    LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# 0            42                  6                  15              2
# 1            66                  3                  28              0
# 2            11                  1                   5              1
# 3            17                  0                  10              0
# 4            74                  7                  36              0
#
#    METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0               4             89.361702          86.666667  21
# 1              16            100.000000          90.000000  31
# 2               5             91.666667                NaN   6
# 3               9            100.000000         100.000000  10
# 4              25             85.057471          77.777778  43

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.455565       0.752220
# INSTRUCTION_COVERED             0.455565             1.000000       0.561240
# BRANCH_MISSED                   0.752220             0.561240       1.000000
# BRANCH_COVERED                  0.476820             0.894344       0.611482
# LINE_MISSED                     0.915319             0.436265       0.707620
# LINE_COVERED                    0.454504             0.964325       0.562278
# COMPLEXITY_MISSED               0.888745             0.465321       0.871260
# COMPLEXITY_COVERED              0.418362             0.930584       0.507205
# METHOD_MISSED                   0.642027             0.066670       0.333766
# METHOD_COVERED                  0.405247             0.850074       0.442141
# Statement_Percentage           -0.883286            -0.321123      -0.632283
# Branch_Percentage              -0.747431            -0.254721      -0.937822
# CC                              0.569363             0.911356       0.629573
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.476820     0.915319      0.454504
# INSTRUCTION_COVERED         0.894344     0.436265      0.964325
# BRANCH_MISSED               0.611482     0.707620      0.562278
# BRANCH_COVERED              1.000000     0.482381      0.901650
# LINE_MISSED                 0.482381     1.000000      0.462180
# LINE_COVERED                0.901650     0.462180      1.000000
# COMPLEXITY_MISSED           0.508171     0.824232      0.461973
# COMPLEXITY_COVERED          0.894994     0.429501      0.965451
# METHOD_MISSED               0.088073     0.641899      0.065766
# METHOD_COVERED              0.736666     0.407016      0.899238
# Statement_Percentage       -0.380692    -0.976087     -0.351115
# Branch_Percentage          -0.244314    -0.665429     -0.251184
# CC                          0.887943     0.570912      0.942240
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.888745            0.418362       0.642027
# INSTRUCTION_COVERED            0.465321            0.930584       0.066670
# BRANCH_MISSED                  0.871260            0.507205       0.333766
# BRANCH_COVERED                 0.508171            0.894994       0.088073
# LINE_MISSED                    0.824232            0.429501       0.641899
# LINE_COVERED                   0.461973            0.965451       0.065766
# COMPLEXITY_MISSED              1.000000            0.430517       0.661025
# COMPLEXITY_COVERED             0.430517            1.000000       0.065107
# METHOD_MISSED                  0.661025            0.065107       1.000000
# METHOD_COVERED                 0.391388            0.944739       0.063948
# Statement_Percentage          -0.800809           -0.325748      -0.698099
# Branch_Percentage             -0.876345           -0.148023      -0.445809
# CC                             0.588072            0.959771       0.237007
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.405247             -0.883286          -0.747431
# INSTRUCTION_COVERED         0.850074             -0.321123          -0.254721
# BRANCH_MISSED               0.442141             -0.632283          -0.937822
# BRANCH_COVERED              0.736666             -0.380692          -0.244314
# LINE_MISSED                 0.407016             -0.976087          -0.665429
# LINE_COVERED                0.899238             -0.351115          -0.251184
# COMPLEXITY_MISSED           0.391388             -0.800809          -0.876345
# COMPLEXITY_COVERED          0.944739             -0.325748          -0.148023
# METHOD_MISSED               0.063948             -0.698099          -0.445809
# METHOD_COVERED              1.000000             -0.308526          -0.129884
# Statement_Percentage       -0.308526              1.000000           0.661603
# Branch_Percentage          -0.129884              0.661603           1.000000
# CC                          0.906191             -0.480142          -0.354947
#
#                             CC
# INSTRUCTION_MISSED    0.569363
# INSTRUCTION_COVERED   0.911356
# BRANCH_MISSED         0.629573
# BRANCH_COVERED        0.887943
# LINE_MISSED           0.570912
# LINE_COVERED          0.942240
# COMPLEXITY_MISSED     0.588072
# COMPLEXITY_COVERED    0.959771
# METHOD_MISSED         0.237007
# METHOD_COVERED        0.906191
# Statement_Percentage -0.480142
# Branch_Percentage    -0.354947
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.480142
# Statement_Percentage -0.480142              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.4192030505355975, pvalue=1.4324344718235615e-09)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.354947
# Branch_Percentage -0.354947           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.3549468388104169, pvalue=4.3805333370648684e-07)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 89.23684210526316

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 83.26675543719485
