# %%
import pandas as pd
import scipy.stats  as stats

# %%
import matplotlib.pyplot as plt

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/configuration/common-configuration-2.3.csv', error_bad_lines=False)

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                           GROUP                                      PACKAGE  \
# 0  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 1  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 2  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 3  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 4  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
#
#                                 CLASS  INSTRUCTION_MISSED  \
# 0              ConfigurationDynaClass                  36
# 1                  DefaultBeanFactory                   7
# 2  BeanHelper.BeanCreationContextImpl                   5
# 3         XMLBeanDeclaration.NodeData                   0
# 4                  XMLBeanDeclaration                  51
#
#    INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  \
# 0                  140              4              26            5
# 1                  257              3              27            0
# 2                   30              0               0            1
# 3                   89              0               2            0
# 4                  315              8              28           13
#
#    LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# 0            42                  6                  15              2
# 1            66                  3                  28              0
# 2            11                  1                   5              1
# 3            17                  0                  10              0
# 4            74                  7                  36              0
#
#    METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0               4             89.361702          86.666667  21
# 1              16            100.000000          90.000000  31
# 2               5             91.666667                NaN   6
# 3               9            100.000000         100.000000  10
# 4              25             85.057471          77.777778  43

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.446790       0.735938
# INSTRUCTION_COVERED             0.446790             1.000000       0.562283
# BRANCH_MISSED                   0.735938             0.562283       1.000000
# BRANCH_COVERED                  0.458869             0.892326       0.616054
# LINE_MISSED                     0.919602             0.424681       0.689591
# LINE_COVERED                    0.448004             0.965483       0.563777
# COMPLEXITY_MISSED               0.893932             0.462901       0.858430
# COMPLEXITY_COVERED              0.407332             0.930986       0.509567
# METHOD_MISSED                   0.658468             0.067286       0.314828
# METHOD_COVERED                  0.398978             0.852153       0.443375
# Statement_Percentage           -0.885554            -0.303041      -0.608355
# Branch_Percentage              -0.742767            -0.254045      -0.937216
# CC                              0.559758             0.911871       0.629049
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.458869     0.919602      0.448004
# INSTRUCTION_COVERED         0.892326     0.424681      0.965483
# BRANCH_MISSED               0.616054     0.689591      0.563777
# BRANCH_COVERED              1.000000     0.458981      0.899819
# LINE_MISSED                 0.458981     1.000000      0.451672
# LINE_COVERED                0.899819     0.451672      1.000000
# COMPLEXITY_MISSED           0.499295     0.832377      0.462169
# COMPLEXITY_COVERED          0.894250     0.414018      0.965089
# METHOD_MISSED               0.076320     0.661472      0.069277
# METHOD_COVERED              0.737169     0.397218      0.899893
# Statement_Percentage       -0.351334    -0.974619     -0.334466
# Branch_Percentage          -0.247781    -0.665585     -0.251286
# CC                          0.886462     0.557738      0.942652
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.893932            0.407332       0.658468
# INSTRUCTION_COVERED            0.462901            0.930986       0.067286
# BRANCH_MISSED                  0.858430            0.509567       0.314828
# BRANCH_COVERED                 0.499295            0.894250       0.076320
# LINE_MISSED                    0.832377            0.414018       0.661472
# LINE_COVERED                   0.462169            0.965089       0.069277
# COMPLEXITY_MISSED              1.000000            0.428028       0.665305
# COMPLEXITY_COVERED             0.428028            1.000000       0.064247
# METHOD_MISSED                  0.665305            0.064247       1.000000
# METHOD_COVERED                 0.393135            0.944994       0.068576
# Statement_Percentage          -0.806192           -0.304122      -0.718181
# Branch_Percentage             -0.871846           -0.147213      -0.436114
# CC                             0.586019            0.960146       0.234959
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.398978             -0.885554          -0.742767
# INSTRUCTION_COVERED         0.852153             -0.303041          -0.254045
# BRANCH_MISSED               0.443375             -0.608355          -0.937216
# BRANCH_COVERED              0.737169             -0.351334          -0.247781
# LINE_MISSED                 0.397218             -0.974619          -0.665585
# LINE_COVERED                0.899893             -0.334466          -0.251286
# COMPLEXITY_MISSED           0.393135             -0.806192          -0.871846
# COMPLEXITY_COVERED          0.944994             -0.304122          -0.147213
# METHOD_MISSED               0.068576             -0.718181          -0.436114
# METHOD_COVERED              1.000000             -0.293118          -0.128022
# Statement_Percentage       -0.293118              1.000000           0.661190
# Branch_Percentage          -0.128022              0.661190           1.000000
# CC                          0.907248             -0.461247          -0.351816
#
#                             CC
# INSTRUCTION_MISSED    0.559758
# INSTRUCTION_COVERED   0.911871
# BRANCH_MISSED         0.629049
# BRANCH_COVERED        0.886462
# LINE_MISSED           0.557738
# LINE_COVERED          0.942652
# COMPLEXITY_MISSED     0.586019
# COMPLEXITY_COVERED    0.960146
# METHOD_MISSED         0.234959
# METHOD_COVERED        0.907248
# Statement_Percentage -0.461247
# Branch_Percentage    -0.351816
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.461247
# Statement_Percentage -0.461247              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.42109627349065804, pvalue=1.0740925932895295e-09)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.351816
# Branch_Percentage -0.351816           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.35181586401830073, pvalue=5.24407199570016e-07)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 89.01202749140893

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 83.29694323144105
