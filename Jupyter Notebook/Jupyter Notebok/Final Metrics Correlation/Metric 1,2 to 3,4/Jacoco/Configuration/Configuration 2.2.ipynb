# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/configuration/common-configuration-2.2.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                           GROUP                                      PACKAGE  \
# 0  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 1  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 2  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 3  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 4  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
#
#                                 CLASS  INSTRUCTION_MISSED  \
# 0              ConfigurationDynaClass                  34
# 1                  DefaultBeanFactory                   7
# 2  BeanHelper.BeanCreationContextImpl                   5
# 3         XMLBeanDeclaration.NodeData                   0
# 4                  XMLBeanDeclaration                  49
#
#    INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  \
# 0                  139              4              26            5
# 1                  257              3              27            1
# 2                   30              0               0            1
# 3                   90              0               2            0
# 4                  315              8              28           12
#
#    LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# 0            47                  6                  15              2
# 1            69                  3                  28              0
# 2            11                  1                   5              1
# 3            17                  0                  10              0
# 4            72                  7                  36              0
#
#    METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0               4             90.384615          86.666667  21
# 1              16             98.571429          90.000000  31
# 2               5             91.666667                NaN   6
# 3               9            100.000000         100.000000  10
# 4              25             85.714286          77.777778  43

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.430931       0.726019
# INSTRUCTION_COVERED             0.430931             1.000000       0.560226
# BRANCH_MISSED                   0.726019             0.560226       1.000000
# BRANCH_COVERED                  0.439363             0.890341       0.612363
# LINE_MISSED                     0.945064             0.411311       0.692024
# LINE_COVERED                    0.430890             0.975381       0.553208
# COMPLEXITY_MISSED               0.893385             0.451555       0.858232
# COMPLEXITY_COVERED              0.388405             0.930753       0.506226
# METHOD_MISSED                   0.668441             0.050773       0.315366
# METHOD_COVERED                  0.381842             0.851743       0.439718
# Statement_Percentage           -0.914983            -0.257386      -0.588131
# Branch_Percentage              -0.746073            -0.249460      -0.936622
# CC                              0.543956             0.912141       0.626743
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.439363     0.945064      0.430890
# INSTRUCTION_COVERED         0.890341     0.411311      0.975381
# BRANCH_MISSED               0.612363     0.692024      0.553208
# BRANCH_COVERED              1.000000     0.433900      0.884036
# LINE_MISSED                 0.433900     1.000000      0.427225
# LINE_COVERED                0.884036     0.427225      1.000000
# COMPLEXITY_MISSED           0.487785     0.857770      0.448019
# COMPLEXITY_COVERED          0.893473     0.389437      0.953090
# METHOD_MISSED               0.060102     0.681380      0.055732
# METHOD_COVERED              0.734774     0.377156      0.893941
# Statement_Percentage       -0.292016    -0.964480     -0.273496
# Branch_Percentage          -0.238356    -0.681550     -0.239513
# CC                          0.885451     0.540734      0.932025
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.893385            0.388405       0.668441
# INSTRUCTION_COVERED            0.451555            0.930753       0.050773
# BRANCH_MISSED                  0.858232            0.506226       0.315366
# BRANCH_COVERED                 0.487785            0.893473       0.060102
# LINE_MISSED                    0.857770            0.389437       0.681380
# LINE_COVERED                   0.448019            0.953090       0.055732
# COMPLEXITY_MISSED              1.000000            0.412035       0.666251
# COMPLEXITY_COVERED             0.412035            1.000000       0.040773
# METHOD_MISSED                  0.666251            0.040773       1.000000
# METHOD_COVERED                 0.376731            0.944575       0.044993
# Statement_Percentage          -0.832007           -0.244612      -0.761353
# Branch_Percentage             -0.874334           -0.138796      -0.451305
# CC                             0.571417            0.959936       0.212642
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.381842             -0.914983          -0.746073
# INSTRUCTION_COVERED         0.851743             -0.257386          -0.249460
# BRANCH_MISSED               0.439718             -0.588131          -0.936622
# BRANCH_COVERED              0.734774             -0.292016          -0.238356
# LINE_MISSED                 0.377156             -0.964480          -0.681550
# LINE_COVERED                0.893941             -0.273496          -0.239513
# COMPLEXITY_MISSED           0.376731             -0.832007          -0.874334
# COMPLEXITY_COVERED          0.944575             -0.244612          -0.138796
# METHOD_MISSED               0.044993             -0.761353          -0.451305
# METHOD_COVERED              1.000000             -0.242067          -0.121191
# Statement_Percentage       -0.242067              1.000000           0.687942
# Branch_Percentage          -0.121191              0.687942           1.000000
# CC                          0.906792             -0.414374          -0.345761
#
#                             CC
# INSTRUCTION_MISSED    0.543956
# INSTRUCTION_COVERED   0.912141
# BRANCH_MISSED         0.626743
# BRANCH_COVERED        0.885451
# LINE_MISSED           0.540734
# LINE_COVERED          0.932025
# COMPLEXITY_MISSED     0.571417
# COMPLEXITY_COVERED    0.959936
# METHOD_MISSED         0.212642
# METHOD_COVERED        0.906792
# Statement_Percentage -0.414374
# Branch_Percentage    -0.345761
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.414374
# Statement_Percentage -0.414374              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.4120488461268272, pvalue=2.6197313234713136e-09)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.345761
# Branch_Percentage -0.345761           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.3457607956011383, pvalue=8.435529689352105e-07)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 88.5417511969488

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 83.26710816777042
