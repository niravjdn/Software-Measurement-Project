# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/lang/lang-v3.4.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-lang3-code-coverage (Apr 4, 2019 12:20...
# 1  commons-lang3-code-coverage (Apr 4, 2019 12:20...
# 2  commons-lang3-code-coverage (Apr 4, 2019 12:20...
# 3  commons-lang3-code-coverage (Apr 4, 2019 12:20...
# 4  commons-lang3-code-coverage (Apr 4, 2019 12:20...
#
#                                    PACKAGE                            CLASS  \
# 0  org.apache.commons.lang3.text.translate    NumericEntityUnescaper.OPTION
# 1  org.apache.commons.lang3.text.translate           NumericEntityUnescaper
# 2  org.apache.commons.lang3.text.translate  UnicodeUnpairedSurrogateRemover
# 3  org.apache.commons.lang3.text.translate              AggregateTranslator
# 4  org.apache.commons.lang3.text.translate           CharSequenceTranslator
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                   0                   34              0               0
# 1                   2                  203              5              43
# 2                   0                   13              0               4
# 3                   0                   37              0               4
# 4                   6                  185              2              16
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            0             1                  0                   1
# 1            0            42                  5                  22
# 2            0             4                  0                   4
# 3            0             8                  0                   4
# 4            2            33                  2                  13
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0              0               1            100.000000                NaN   1
# 1              0               3            100.000000          89.583333  27
# 2              0               2            100.000000         100.000000   4
# 3              0               2            100.000000         100.000000   4
# 4              0               6             94.285714          88.888889  15

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.384234       0.669267
# INSTRUCTION_COVERED             0.384234             1.000000       0.476662
# BRANCH_MISSED                   0.669267             0.476662       1.000000
# BRANCH_COVERED                  0.426206             0.656059       0.700378
# LINE_MISSED                     0.947845             0.325056       0.558617
# LINE_COVERED                    0.409222             0.977555       0.491474
# COMPLEXITY_MISSED               0.860358             0.346398       0.810114
# COMPLEXITY_COVERED              0.372044             0.929122       0.498664
# METHOD_MISSED                   0.677305             0.017098       0.296197
# METHOD_COVERED                  0.372315             0.923895       0.451463
# Statement_Percentage           -0.825964             0.027799      -0.352357
# Branch_Percentage              -0.617801            -0.047953      -0.760211
# CC                              0.543688             0.881378       0.622598
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.426206     0.947845      0.409222
# INSTRUCTION_COVERED         0.656059     0.325056      0.977555
# BRANCH_MISSED               0.700378     0.558617      0.491474
# BRANCH_COVERED              1.000000     0.342087      0.671823
# LINE_MISSED                 0.342087     1.000000      0.354360
# LINE_COVERED                0.671823     0.354360      1.000000
# COMPLEXITY_MISSED           0.535583     0.787526      0.369392
# COMPLEXITY_COVERED          0.750505     0.318812      0.947276
# METHOD_MISSED               0.088538     0.730629      0.041020
# METHOD_COVERED              0.639857     0.322890      0.942757
# Statement_Percentage       -0.101833    -0.881072     -0.001831
# Branch_Percentage           0.090434    -0.510502     -0.034823
# CC                          0.758085     0.483927      0.907382
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.860358            0.372044       0.677305
# INSTRUCTION_COVERED            0.346398            0.929122       0.017098
# BRANCH_MISSED                  0.810114            0.498664       0.296197
# BRANCH_COVERED                 0.535583            0.750505       0.088538
# LINE_MISSED                    0.787526            0.318812       0.730629
# LINE_COVERED                   0.369392            0.947276       0.041020
# COMPLEXITY_MISSED              1.000000            0.361784       0.700822
# COMPLEXITY_COVERED             0.361784            1.000000       0.030965
# METHOD_MISSED                  0.700822            0.030965       1.000000
# METHOD_COVERED                 0.332417            0.976089       0.042726
# Statement_Percentage          -0.698693            0.031506      -0.770104
# Branch_Percentage             -0.682329            0.126294      -0.385960
# CC                             0.548597            0.949288       0.217043
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.372315             -0.825964          -0.617801
# INSTRUCTION_COVERED         0.923895              0.027799          -0.047953
# BRANCH_MISSED               0.451463             -0.352357          -0.760211
# BRANCH_COVERED              0.639857             -0.101833           0.090434
# LINE_MISSED                 0.322890             -0.881072          -0.510502
# LINE_COVERED                0.942757             -0.001831          -0.034823
# COMPLEXITY_MISSED           0.332417             -0.698693          -0.682329
# COMPLEXITY_COVERED          0.976089              0.031506           0.126294
# METHOD_MISSED               0.042726             -0.770104          -0.385960
# METHOD_COVERED              1.000000              0.030420           0.033006
# Statement_Percentage        0.030420              1.000000           0.610901
# Branch_Percentage           0.033006              0.610901           1.000000
# CC                          0.925142             -0.172356          -0.084659
#
#                             CC
# INSTRUCTION_MISSED    0.543688
# INSTRUCTION_COVERED   0.881378
# BRANCH_MISSED         0.622598
# BRANCH_COVERED        0.758085
# LINE_MISSED           0.483927
# LINE_COVERED          0.907382
# COMPLEXITY_MISSED     0.548597
# COMPLEXITY_COVERED    0.949288
# METHOD_MISSED         0.217043
# METHOD_COVERED        0.925142
# Statement_Percentage -0.172356
# Branch_Percentage    -0.084659
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.172356
# Statement_Percentage -0.172356              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.08740754111016641, pvalue=0.1827058627891878)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.084659
# Branch_Percentage -0.084659           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.08465883449605215, pvalue=0.19690695571672853)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 92.82312402607378

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 82.91500042542329
