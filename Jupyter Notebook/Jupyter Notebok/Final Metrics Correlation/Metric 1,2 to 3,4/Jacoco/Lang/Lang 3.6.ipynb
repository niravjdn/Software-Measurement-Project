# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/lang/lang-v3.6.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-lang3-code-coverage (Apr 4, 2019 12:15...
# 1  commons-lang3-code-coverage (Apr 4, 2019 12:15...
# 2  commons-lang3-code-coverage (Apr 4, 2019 12:15...
# 3  commons-lang3-code-coverage (Apr 4, 2019 12:15...
# 4  commons-lang3-code-coverage (Apr 4, 2019 12:15...
#
#                     PACKAGE                            CLASS  \
# 0  org.apache.commons.lang3      CharRange.CharacterIterator
# 1  org.apache.commons.lang3  ClassUtils.new Iterable() {...}
# 2  org.apache.commons.lang3                        EnumUtils
# 3  org.apache.commons.lang3                         Validate
# 4  org.apache.commons.lang3                  AnnotationUtils
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                   0                  130              0              18
# 1                   0                   21              0               0
# 2                   0                  362              1              25
# 3                  22                  795             17             107
# 4                  43                  457              8              84
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            0            36                  0                  14
# 1            0             5                  0                   2
# 2            0            64                  1                  25
# 3            6           144                 17                  96
# 4           15            95                  9                  48
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage   CC
# 0              0               5            100.000000         100.000000   14
# 1              0               2            100.000000                NaN    2
# 2              0              13            100.000000          96.153846   26
# 3              2              49             96.000000          86.290323  113
# 4              1              10             86.363636          91.304348   57

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.326093       0.623472
# INSTRUCTION_COVERED             0.326093             1.000000       0.457339
# BRANCH_MISSED                   0.623472             0.457339       1.000000
# BRANCH_COVERED                  0.377754             0.631478       0.674109
# LINE_MISSED                     0.960359             0.281040       0.541413
# LINE_COVERED                    0.359195             0.972280       0.473952
# COMPLEXITY_MISSED               0.843094             0.301844       0.789752
# COMPLEXITY_COVERED              0.311701             0.919656       0.481211
# METHOD_MISSED                   0.699586            -0.012588       0.282088
# METHOD_COVERED                  0.315865             0.911977       0.432053
# Statement_Percentage           -0.860167             0.033600      -0.347044
# Branch_Percentage              -0.629981            -0.102873      -0.795092
# CC                              0.491212             0.866613       0.599623
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.377754     0.960359      0.359195
# INSTRUCTION_COVERED         0.631478     0.281040      0.972280
# BRANCH_MISSED               0.674109     0.541413      0.473952
# BRANCH_COVERED              1.000000     0.316692      0.644218
# LINE_MISSED                 0.316692     1.000000      0.316021
# LINE_COVERED                0.644218     0.316021      1.000000
# COMPLEXITY_MISSED           0.494430     0.794493      0.333049
# COMPLEXITY_COVERED          0.729573     0.270340      0.941404
# METHOD_MISSED               0.072039     0.738469      0.019657
# METHOD_COVERED              0.610560     0.274754      0.935979
# Statement_Percentage       -0.103563    -0.900268     -0.003968
# Branch_Percentage           0.079377    -0.539652     -0.100103
# CC                          0.730768     0.449494      0.899318
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.843094            0.311701       0.699586
# INSTRUCTION_COVERED            0.301844            0.919656      -0.012588
# BRANCH_MISSED                  0.789752            0.481211       0.282088
# BRANCH_COVERED                 0.494430            0.729573       0.072039
# LINE_MISSED                    0.794493            0.270340       0.738469
# LINE_COVERED                   0.333049            0.941404       0.019657
# COMPLEXITY_MISSED              1.000000            0.315198       0.718520
# COMPLEXITY_COVERED             0.315198            1.000000      -0.003445
# METHOD_MISSED                  0.718520           -0.003445       1.000000
# METHOD_COVERED                 0.284779            0.974907       0.008114
# Statement_Percentage          -0.719716            0.041927      -0.780750
# Branch_Percentage             -0.725142            0.048203      -0.387523
# CC                             0.511386            0.944289       0.198963
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.315865             -0.860167          -0.629981
# INSTRUCTION_COVERED         0.911977              0.033600          -0.102873
# BRANCH_MISSED               0.432053             -0.347044          -0.795092
# BRANCH_COVERED              0.610560             -0.103563           0.079377
# LINE_MISSED                 0.274754             -0.900268          -0.539652
# LINE_COVERED                0.935979             -0.003968          -0.100103
# COMPLEXITY_MISSED           0.284779             -0.719716          -0.725142
# COMPLEXITY_COVERED          0.974907              0.041927           0.048203
# METHOD_MISSED               0.008114             -0.780750          -0.387523
# METHOD_COVERED              1.000000              0.040512          -0.032822
# Statement_Percentage        0.040512              1.000000           0.580373
# Branch_Percentage          -0.032822              0.580373           1.000000
# CC                          0.918016             -0.173687          -0.147347
#
#                             CC
# INSTRUCTION_MISSED    0.491212
# INSTRUCTION_COVERED   0.866613
# BRANCH_MISSED         0.599623
# BRANCH_COVERED        0.730768
# LINE_MISSED           0.449494
# LINE_COVERED          0.899318
# COMPLEXITY_MISSED     0.511386
# COMPLEXITY_COVERED    0.944289
# METHOD_MISSED         0.198963
# METHOD_COVERED        0.918016
# Statement_Percentage -0.173687
# Branch_Percentage    -0.147347
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.173687
# Statement_Percentage -0.173687              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.1056355177998964, pvalue=0.08792206015576454)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.147347
# Branch_Percentage -0.147347           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.14734666475679406, pvalue=0.017002599231068217)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 93.35251187396223

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 84.15810524664732
