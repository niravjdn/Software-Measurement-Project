# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/lang/lang-v3.7.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-lang3-code-coverage (Apr 4, 2019 12:12...
# 1  commons-lang3-code-coverage (Apr 4, 2019 12:12...
# 2  commons-lang3-code-coverage (Apr 4, 2019 12:12...
# 3  commons-lang3-code-coverage (Apr 4, 2019 12:12...
# 4  commons-lang3-code-coverage (Apr 4, 2019 12:12...
#
#                     PACKAGE                              CLASS  \
# 0  org.apache.commons.lang3                            CharSet
# 1  org.apache.commons.lang3             SerializationException
# 2  org.apache.commons.lang3  ArrayUtils.new Comparator() {...}
# 3  org.apache.commons.lang3                        ObjectUtils
# 4  org.apache.commons.lang3                       CharSetUtils
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                   0                  304              0              34
# 1                   0                   16              0               0
# 2                   0                    7              0               0
# 3                  31                  614              1              87
# 4                   0                  255              1              53
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            0            58                  0                  26
# 1            0             8                  0                   4
# 2            0             3                  0                   2
# 3            6           145                  1                  80
# 4            0            61                  1                  34
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0              0               9             100.00000         100.000000  26
# 1              0               4             100.00000                NaN   4
# 2              0               2             100.00000                NaN   2
# 3              0              37              96.02649          98.863636  81
# 4              0               8             100.00000          98.148148  35

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.328841       0.623193
# INSTRUCTION_COVERED             0.328841             1.000000       0.455362
# BRANCH_MISSED                   0.623193             0.455362       1.000000
# BRANCH_COVERED                  0.376766             0.630288       0.677202
# LINE_MISSED                     0.959760             0.284294       0.536998
# LINE_COVERED                    0.360270             0.972719       0.471888
# COMPLEXITY_MISSED               0.845396             0.306011       0.786709
# COMPLEXITY_COVERED              0.314070             0.920829       0.481932
# METHOD_MISSED                   0.702927            -0.004669       0.280762
# METHOD_COVERED                  0.317623             0.913683       0.431596
# Statement_Percentage           -0.862351             0.024679      -0.347440
# Branch_Percentage              -0.633855            -0.099601      -0.800366
# CC                              0.492755             0.868630       0.598289
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.376766     0.959760      0.360270
# INSTRUCTION_COVERED         0.630288     0.284294      0.972719
# BRANCH_MISSED               0.677202     0.536998      0.471888
# BRANCH_COVERED              1.000000     0.314654      0.642566
# LINE_MISSED                 0.314654     1.000000      0.317766
# LINE_COVERED                0.642566     0.317766      1.000000
# COMPLEXITY_MISSED           0.493302     0.795151      0.335793
# COMPLEXITY_COVERED          0.728574     0.272889      0.941907
# METHOD_MISSED               0.072139     0.742643      0.025881
# METHOD_COVERED              0.610011     0.276707      0.936897
# Statement_Percentage       -0.105168    -0.902412     -0.010984
# Branch_Percentage           0.064792    -0.536554     -0.097922
# CC                          0.729260     0.450756      0.900092
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.845396            0.314070       0.702927
# INSTRUCTION_COVERED            0.306011            0.920829      -0.004669
# BRANCH_MISSED                  0.786709            0.481932       0.280762
# BRANCH_COVERED                 0.493302            0.728574       0.072139
# LINE_MISSED                    0.795151            0.272889       0.742643
# LINE_COVERED                   0.335793            0.941907       0.025881
# COMPLEXITY_MISSED              1.000000            0.318967       0.721429
# COMPLEXITY_COVERED             0.318967            1.000000       0.002891
# METHOD_MISSED                  0.721429            0.002891       1.000000
# METHOD_COVERED                 0.288577            0.975641       0.014776
# Statement_Percentage          -0.721982            0.034306      -0.782379
# Branch_Percentage             -0.725954            0.042989      -0.378594
# CC                             0.513789            0.944878       0.204644
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.317623             -0.862351          -0.633855
# INSTRUCTION_COVERED         0.913683              0.024679          -0.099601
# BRANCH_MISSED               0.431596             -0.347440          -0.800366
# BRANCH_COVERED              0.610011             -0.105168           0.064792
# LINE_MISSED                 0.276707             -0.902412          -0.536554
# LINE_COVERED                0.936897             -0.010984          -0.097922
# COMPLEXITY_MISSED           0.288577             -0.721982          -0.725954
# COMPLEXITY_COVERED          0.975641              0.034306           0.042989
# METHOD_MISSED               0.014776             -0.782379          -0.378594
# METHOD_COVERED              1.000000              0.033456          -0.032965
# Statement_Percentage        0.033456              1.000000           0.576722
# Branch_Percentage          -0.032965              0.576722           1.000000
# CC                          0.919194             -0.180390          -0.150860
#
#                             CC
# INSTRUCTION_MISSED    0.492755
# INSTRUCTION_COVERED   0.868630
# BRANCH_MISSED         0.598289
# BRANCH_COVERED        0.729260
# LINE_MISSED           0.450756
# LINE_COVERED          0.900092
# COMPLEXITY_MISSED     0.513789
# COMPLEXITY_COVERED    0.944878
# METHOD_MISSED         0.204644
# METHOD_COVERED        0.919194
# Statement_Percentage -0.180390
# Branch_Percentage    -0.150860
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                            CC  Statement_Percentage
# CC                    1.00000              -0.18039
# Statement_Percentage -0.18039               1.00000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.11028039410137482, pvalue=0.07364678044286935)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                         CC  Branch_Percentage
# CC                 1.00000           -0.15086
# Branch_Percentage -0.15086            1.00000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.15086029331787776, pvalue=0.014142756428951178)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 93.30863581396241

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 84.16529958596985
