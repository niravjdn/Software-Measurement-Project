# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/lang/lang-v3.8.1.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-lang3-code-coverage (Apr 4, 2019 12:05...
# 1  commons-lang3-code-coverage (Apr 4, 2019 12:05...
# 2  commons-lang3-code-coverage (Apr 4, 2019 12:05...
# 3  commons-lang3-code-coverage (Apr 4, 2019 12:05...
# 4  commons-lang3-code-coverage (Apr 4, 2019 12:05...
#
#                     PACKAGE                    CLASS  INSTRUCTION_MISSED  \
# 0  org.apache.commons.lang3                CharRange                   0
# 1  org.apache.commons.lang3  NotImplementedException                   0
# 2  org.apache.commons.lang3                 Validate                  22
# 3  org.apache.commons.lang3         ObjectUtils.Null                   0
# 4  org.apache.commons.lang3                CharUtils                   0
#
#    INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  \
# 0                  240              1              47            0
# 1                   41              0               0            0
# 2                  795             17             107            6
# 3                    5              0               0            0
# 4                  343              0              54            0
#
#    LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# 0            43                  1                  37              0
# 1            16                  0                   7              0
# 2           144                 17                  96              2
# 3             3                  0                   2              0
# 4            55                  0                  52              0
#
#    METHOD_COVERED  Statement_Percentage  Branch_Percentage   CC
# 0              14                 100.0          97.916667   38
# 1               7                 100.0                NaN    7
# 2              49                  96.0          86.290323  113
# 3               2                 100.0                NaN    2
# 4              25                 100.0         100.000000   52

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.332205       0.615723
# INSTRUCTION_COVERED             0.332205             1.000000       0.445974
# BRANCH_MISSED                   0.615723             0.445974       1.000000
# BRANCH_COVERED                  0.377896             0.633284       0.660006
# LINE_MISSED                     0.959372             0.285311       0.527393
# LINE_COVERED                    0.365015             0.972697       0.462882
# COMPLEXITY_MISSED               0.843217             0.301924       0.780025
# COMPLEXITY_COVERED              0.316094             0.921375       0.471018
# METHOD_MISSED                   0.708815             0.006519       0.284693
# METHOD_COVERED                  0.317736             0.913979       0.422201
# Statement_Percentage           -0.860949             0.024120      -0.341174
# Branch_Percentage              -0.609994            -0.087859      -0.805916
# CC                              0.495007             0.869064       0.588568
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.377896     0.959372      0.365015
# INSTRUCTION_COVERED         0.633284     0.285311      0.972697
# BRANCH_MISSED               0.660006     0.527393      0.462882
# BRANCH_COVERED              1.000000     0.313214      0.645013
# LINE_MISSED                 0.313214     1.000000      0.320430
# LINE_COVERED                0.645013     0.320430      1.000000
# COMPLEXITY_MISSED           0.492423     0.792212      0.333462
# COMPLEXITY_COVERED          0.730688     0.272553      0.941859
# METHOD_MISSED               0.088886     0.749654      0.039620
# METHOD_COVERED              0.611671     0.275611      0.936624
# Statement_Percentage       -0.104806    -0.902272     -0.013524
# Branch_Percentage           0.071173    -0.513057     -0.085991
# CC                          0.730038     0.451003      0.900523
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.843217            0.316094       0.708815
# INSTRUCTION_COVERED            0.301924            0.921375       0.006519
# BRANCH_MISSED                  0.780025            0.471018       0.284693
# BRANCH_COVERED                 0.492423            0.730688       0.088886
# LINE_MISSED                    0.792212            0.272553       0.749654
# LINE_COVERED                   0.333462            0.941859       0.039620
# COMPLEXITY_MISSED              1.000000            0.315827       0.731732
# COMPLEXITY_COVERED             0.315827            1.000000       0.015872
# METHOD_MISSED                  0.731732            0.015872       1.000000
# METHOD_COVERED                 0.286093            0.975584       0.029089
# Statement_Percentage          -0.721012            0.034152      -0.781566
# Branch_Percentage             -0.708063            0.052524      -0.346440
# CC                             0.511421            0.944742       0.216847
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.317736             -0.860949          -0.609994
# INSTRUCTION_COVERED         0.913979              0.024120          -0.087859
# BRANCH_MISSED               0.422201             -0.341174          -0.805916
# BRANCH_COVERED              0.611671             -0.104806           0.071173
# LINE_MISSED                 0.275611             -0.902272          -0.513057
# LINE_COVERED                0.936624             -0.013524          -0.085991
# COMPLEXITY_MISSED           0.286093             -0.721012          -0.708063
# COMPLEXITY_COVERED          0.975584              0.034152           0.052524
# METHOD_MISSED               0.029089             -0.781566          -0.346440
# METHOD_COVERED              1.000000              0.034434          -0.023172
# Statement_Percentage        0.034434              1.000000           0.554291
# Branch_Percentage          -0.023172              0.554291           1.000000
# CC                          0.919357             -0.181031          -0.139671
#
#                             CC
# INSTRUCTION_MISSED    0.495007
# INSTRUCTION_COVERED   0.869064
# BRANCH_MISSED         0.588568
# BRANCH_COVERED        0.730038
# LINE_MISSED           0.451003
# LINE_COVERED          0.900523
# COMPLEXITY_MISSED     0.511421
# COMPLEXITY_COVERED    0.944742
# METHOD_MISSED         0.216847
# METHOD_COVERED        0.919357
# Statement_Percentage -0.181031
# Branch_Percentage    -0.139671
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.181031
# Statement_Percentage -0.181031              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.11555261459342171, pvalue=0.05934785685038709)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.139671
# Branch_Percentage -0.139671           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.13967078633400887, pvalue=0.022446153997853636)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 93.32941131817665

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 84.33201212403823
