# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/lang/lang-v3.5.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-lang3-code-coverage (Apr 4, 2019 12:18...
# 1  commons-lang3-code-coverage (Apr 4, 2019 12:18...
# 2  commons-lang3-code-coverage (Apr 4, 2019 12:18...
# 3  commons-lang3-code-coverage (Apr 4, 2019 12:18...
# 4  commons-lang3-code-coverage (Apr 4, 2019 12:18...
#
#                                    PACKAGE                            CLASS  \
# 0  org.apache.commons.lang3.text.translate  UnicodeUnpairedSurrogateRemover
# 1  org.apache.commons.lang3.text.translate              CodePointTranslator
# 2  org.apache.commons.lang3.text.translate           NumericEntityUnescaper
# 3  org.apache.commons.lang3.text.translate                   UnicodeEscaper
# 4  org.apache.commons.lang3.text.translate               JavaUnicodeEscaper
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                   0                   13              0               4
# 1                   0                   18              0               2
# 2                   2                  203              5              43
# 3                  15                  105              0              12
# 4                  15                   34              0               0
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            0             4                  0                   4
# 1            0             4                  0                   3
# 2            0            42                  5                  22
# 3            3            23                  2                  12
# 4            3             5                  3                   3
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0              0               2            100.000000         100.000000   4
# 1              0               2            100.000000         100.000000   3
# 2              0               3            100.000000          89.583333  27
# 3              2               6             88.461538         100.000000  14
# 4              3               3             62.500000                NaN   6

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.366168       0.653807
# INSTRUCTION_COVERED             0.366168             1.000000       0.480184
# BRANCH_MISSED                   0.653807             0.480184       1.000000
# BRANCH_COVERED                  0.414354             0.644349       0.695867
# LINE_MISSED                     0.943002             0.300202       0.534157
# LINE_COVERED                    0.396264             0.972531       0.497017
# COMPLEXITY_MISSED               0.864027             0.337981       0.797602
# COMPLEXITY_COVERED              0.357717             0.921974       0.506279
# METHOD_MISSED                   0.693513             0.020920       0.282487
# METHOD_COVERED                  0.357635             0.914641       0.461266
# Statement_Percentage           -0.832227             0.031099      -0.336112
# Branch_Percentage              -0.631295            -0.118032      -0.795456
# CC                              0.531761             0.872150       0.620853
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.414354     0.943002      0.396264
# INSTRUCTION_COVERED         0.644349     0.300202      0.972531
# BRANCH_MISSED               0.695867     0.534157      0.497017
# BRANCH_COVERED              1.000000     0.323718      0.660638
# LINE_MISSED                 0.323718     1.000000      0.333053
# LINE_COVERED                0.660638     0.333053      1.000000
# COMPLEXITY_MISSED           0.525090     0.785545      0.366426
# COMPLEXITY_COVERED          0.742639     0.296628      0.944506
# METHOD_MISSED               0.094566     0.748296      0.049407
# METHOD_COVERED              0.625345     0.299488      0.938388
# Statement_Percentage       -0.100310    -0.892454     -0.003791
# Branch_Percentage           0.027958    -0.511247     -0.107608
# CC                          0.747196     0.465873      0.904343
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.864027            0.357717       0.693513
# INSTRUCTION_COVERED            0.337981            0.921974       0.020920
# BRANCH_MISSED                  0.797602            0.506279       0.282487
# BRANCH_COVERED                 0.525090            0.742639       0.094566
# LINE_MISSED                    0.785545            0.296628       0.748296
# LINE_COVERED                   0.366426            0.944506       0.049407
# COMPLEXITY_MISSED              1.000000            0.355277       0.710594
# COMPLEXITY_COVERED             0.355277            1.000000       0.034549
# METHOD_MISSED                  0.710594            0.034549       1.000000
# METHOD_COVERED                 0.326889            0.974454       0.044919
# Statement_Percentage          -0.702901            0.033370      -0.779242
# Branch_Percentage             -0.718611            0.030185      -0.346665
# CC                             0.544043            0.947399       0.224542
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.357635             -0.832227          -0.631295
# INSTRUCTION_COVERED         0.914641              0.031099          -0.118032
# BRANCH_MISSED               0.461266             -0.336112          -0.795456
# BRANCH_COVERED              0.625345             -0.100310           0.027958
# LINE_MISSED                 0.299488             -0.892454          -0.511247
# LINE_COVERED                0.938388             -0.003791          -0.107608
# COMPLEXITY_MISSED           0.326889             -0.702901          -0.718611
# COMPLEXITY_COVERED          0.974454              0.033370           0.030185
# METHOD_MISSED               0.044919             -0.779242          -0.346665
# METHOD_COVERED              1.000000              0.033539          -0.056533
# Statement_Percentage        0.033539              1.000000           0.563625
# Branch_Percentage          -0.056533              0.563625           1.000000
# CC                          0.921314             -0.174803          -0.171710
#
#                             CC
# INSTRUCTION_MISSED    0.531761
# INSTRUCTION_COVERED   0.872150
# BRANCH_MISSED         0.620853
# BRANCH_COVERED        0.747196
# LINE_MISSED           0.465873
# LINE_COVERED          0.904343
# COMPLEXITY_MISSED     0.544043
# COMPLEXITY_COVERED    0.947399
# METHOD_MISSED         0.224542
# METHOD_COVERED        0.921314
# Statement_Percentage -0.174803
# Branch_Percentage    -0.171710
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.174803
# Statement_Percentage -0.174803              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.1165127071423228, pvalue=0.06064799587223249)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                         CC  Branch_Percentage
# CC                 1.00000           -0.17171
# Branch_Percentage -0.17171            1.00000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.1717097589800268, pvalue=0.005502480539293128)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 92.81859942629035

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 82.20738413197172
