# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/collection/collections-v3.2.1.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-collections (Apr 2, 2019 9:30:25 PM)/c...
# 1  commons-collections (Apr 2, 2019 9:30:25 PM)/c...
# 2  commons-collections (Apr 2, 2019 9:30:25 PM)/c...
# 3  commons-collections (Apr 2, 2019 9:30:25 PM)/c...
# 4  commons-collections (Apr 2, 2019 9:30:25 PM)/c...
#
#                                   PACKAGE                           CLASS  \
# 0  org.apache.commons.collections.bidimap  AbstractSortedBidiMapDecorator
# 1  org.apache.commons.collections.bidimap                TreeBidiMap.View
# 2  org.apache.commons.collections.bidimap    AbstractDualBidiMap.EntrySet
# 3  org.apache.commons.collections.bidimap         DualTreeBidiMap.ViewMap
# 4  org.apache.commons.collections.bidimap             AbstractDualBidiMap
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                  24                    8              0               0
# 1                   0                   58              0               4
# 2                   0                   70              1               9
# 3                  28                   40              0               2
# 4                   0                  368              0              18
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            5             3                  5                   2
# 1            0            12                  0                   8
# 2            0            14                  1                   7
# 3            3             8                  3                   4
# 4            0            68                  0                  35
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0              5               2             37.500000                NaN   7
# 1              0               6            100.000000              100.0   8
# 2              0               3            100.000000               90.0   8
# 3              3               3             72.727273              100.0   7
# 4              0              26            100.000000              100.0  35

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.465145       0.743762
# INSTRUCTION_COVERED             0.465145             1.000000       0.579054
# BRANCH_MISSED                   0.743762             0.579054       1.000000
# BRANCH_COVERED                  0.416042             0.834035       0.610739
# LINE_MISSED                     0.957842             0.420367       0.685558
# LINE_COVERED                    0.468554             0.986220       0.575213
# COMPLEXITY_MISSED               0.865463             0.395747       0.815000
# COMPLEXITY_COVERED              0.372651             0.919174       0.489206
# METHOD_MISSED                   0.683531             0.022259       0.324916
# METHOD_COVERED                  0.380269             0.875994       0.450531
# Statement_Percentage           -0.734260             0.082449      -0.366416
# Branch_Percentage              -0.614287             0.019596      -0.735249
# CC                              0.615277             0.852672       0.667753
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.416042     0.957842      0.468554
# INSTRUCTION_COVERED         0.834035     0.420367      0.986220
# BRANCH_MISSED               0.610739     0.685558      0.575213
# BRANCH_COVERED              1.000000     0.382016      0.819509
# LINE_MISSED                 0.382016     1.000000      0.437091
# LINE_COVERED                0.819509     0.437091      1.000000
# COMPLEXITY_MISSED           0.450698     0.866269      0.401230
# COMPLEXITY_COVERED          0.828842     0.344155      0.918061
# METHOD_MISSED               0.034456     0.720802      0.034672
# METHOD_COVERED              0.682114     0.346906      0.879760
# Statement_Percentage        0.021092    -0.785798      0.069843
# Branch_Percentage           0.228823    -0.553907      0.009855
# CC                          0.802332     0.600727      0.853912
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.865463            0.372651       0.683531
# INSTRUCTION_COVERED            0.395747            0.919174       0.022259
# BRANCH_MISSED                  0.815000            0.489206       0.324916
# BRANCH_COVERED                 0.450698            0.828842       0.034456
# LINE_MISSED                    0.866269            0.344155       0.720802
# LINE_COVERED                   0.401230            0.918061       0.034672
# COMPLEXITY_MISSED              1.000000            0.342148       0.719505
# COMPLEXITY_COVERED             0.342148            1.000000       0.010258
# METHOD_MISSED                  0.719505            0.010258       1.000000
# METHOD_COVERED                 0.317497            0.958391       0.024951
# Statement_Percentage          -0.691582            0.110144      -0.790532
# Branch_Percentage             -0.664220            0.151793      -0.434228
# CC                             0.630895            0.902460       0.281696
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.380269             -0.734260          -0.614287
# INSTRUCTION_COVERED         0.875994              0.082449           0.019596
# BRANCH_MISSED               0.450531             -0.366416          -0.735249
# BRANCH_COVERED              0.682114              0.021092           0.228823
# LINE_MISSED                 0.346906             -0.785798          -0.553907
# LINE_COVERED                0.879760              0.069843           0.009855
# COMPLEXITY_MISSED           0.317497             -0.691582          -0.664220
# COMPLEXITY_COVERED          0.958391              0.110144           0.151793
# METHOD_MISSED               0.024951             -0.790532          -0.434228
# METHOD_COVERED              1.000000              0.095964           0.033576
# Statement_Percentage        0.095964              1.000000           0.621813
# Branch_Percentage           0.033576              0.621813           1.000000
# CC                          0.860078             -0.172176          -0.101600
#
#                             CC
# INSTRUCTION_MISSED    0.615277
# INSTRUCTION_COVERED   0.852672
# BRANCH_MISSED         0.667753
# BRANCH_COVERED        0.802332
# LINE_MISSED           0.600727
# LINE_COVERED          0.853912
# COMPLEXITY_MISSED     0.630895
# COMPLEXITY_COVERED    0.902460
# METHOD_MISSED         0.281696
# METHOD_COVERED        0.860078
# Statement_Percentage -0.172176
# Branch_Percentage    -0.101600
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.172176
# Statement_Percentage -0.172176              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.06589123650905858, pvalue=0.14363561625687324)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                        CC  Branch_Percentage
# CC                 1.0000            -0.1016
# Branch_Percentage -0.1016             1.0000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.10160008317832783, pvalue=0.02392692876233776)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 84.72549583213566

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 73.04813915857605
