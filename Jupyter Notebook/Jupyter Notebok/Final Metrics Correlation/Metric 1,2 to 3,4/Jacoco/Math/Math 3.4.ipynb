# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/collection/collections-v3.2.2.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-collections (1) (Apr 2, 2019 8:36:46 P...
# 1  commons-collections (1) (Apr 2, 2019 8:36:46 P...
# 2  commons-collections (1) (Apr 2, 2019 8:36:46 P...
# 3  commons-collections (1) (Apr 2, 2019 8:36:46 P...
# 4  commons-collections (1) (Apr 2, 2019 8:36:46 P...
#
#                                   PACKAGE                         CLASS  \
# 0  org.apache.commons.collections.bidimap  AbstractDualBidiMap.MapEntry
# 1  org.apache.commons.collections.bidimap  AbstractDualBidiMap.EntrySet
# 2  org.apache.commons.collections.bidimap         TreeBidiMap.EntryView
# 3  org.apache.commons.collections.bidimap     UnmodifiableSortedBidiMap
# 4  org.apache.commons.collections.bidimap    UnmodifiableOrderedBidiMap
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                   0                   44              0               4
# 1                   0                   70              1               9
# 2                   2                   78              1              11
# 3                   5                  106              1               3
# 4                   2                   81              1               3
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            0            10                  0                   4
# 1            0            14                  1                   7
# 2            1            17                  1                   8
# 3            2            29                  2                  18
# 4            1            23                  1                  15
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0              0               2            100.000000         100.000000   4
# 1              0               3            100.000000          90.000000   8
# 2              0               3             94.444444          91.666667   9
# 3              1              17             93.548387          75.000000  20
# 4              0              14             95.833333          75.000000  16

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.462858       0.740123
# INSTRUCTION_COVERED             0.462858             1.000000       0.567780
# BRANCH_MISSED                   0.740123             0.567780       1.000000
# BRANCH_COVERED                  0.419867             0.831165       0.601711
# LINE_MISSED                     0.948415             0.418062       0.687496
# LINE_COVERED                    0.465377             0.985495       0.567733
# COMPLEXITY_MISSED               0.855814             0.392307       0.822978
# COMPLEXITY_COVERED              0.370522             0.920121       0.479431
# METHOD_MISSED                   0.676460             0.024581       0.337561
# METHOD_COVERED                  0.376100             0.878904       0.441295
# Statement_Percentage           -0.730579             0.070668      -0.383912
# Branch_Percentage              -0.597543             0.032469      -0.736220
# CC                              0.610218             0.854028       0.660673
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.419867     0.948415      0.465377
# INSTRUCTION_COVERED         0.831165     0.418062      0.985495
# BRANCH_MISSED               0.601711     0.687496      0.567733
# BRANCH_COVERED              1.000000     0.374466      0.813163
# LINE_MISSED                 0.374466     1.000000      0.437891
# LINE_COVERED                0.813163     0.437891      1.000000
# COMPLEXITY_MISSED           0.447825     0.864519      0.401898
# COMPLEXITY_COVERED          0.828411     0.340262      0.916982
# METHOD_MISSED               0.035102     0.723755      0.040257
# METHOD_COVERED              0.685572     0.343931      0.881400
# Statement_Percentage        0.018448    -0.795129      0.053441
# Branch_Percentage           0.242592    -0.552741      0.015611
# CC                          0.801718     0.596361      0.854303
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.855814            0.370522       0.676460
# INSTRUCTION_COVERED            0.392307            0.920121       0.024581
# BRANCH_MISSED                  0.822978            0.479431       0.337561
# BRANCH_COVERED                 0.447825            0.828411       0.035102
# LINE_MISSED                    0.864519            0.340262       0.723755
# LINE_COVERED                   0.401898            0.916982       0.040257
# COMPLEXITY_MISSED              1.000000            0.336820       0.718802
# COMPLEXITY_COVERED             0.336820            1.000000       0.008654
# METHOD_MISSED                  0.718802            0.008654       1.000000
# METHOD_COVERED                 0.311520            0.960178       0.021652
# Statement_Percentage          -0.697592            0.103144      -0.792094
# Branch_Percentage             -0.666342            0.161680      -0.443972
# CC                             0.625108            0.903361       0.280353
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.376100             -0.730579          -0.597543
# INSTRUCTION_COVERED         0.878904              0.070668           0.032469
# BRANCH_MISSED               0.441295             -0.383912          -0.736220
# BRANCH_COVERED              0.685572              0.018448           0.242592
# LINE_MISSED                 0.343931             -0.795129          -0.552741
# LINE_COVERED                0.881400              0.053441           0.015611
# COMPLEXITY_MISSED           0.311520             -0.697592          -0.666342
# COMPLEXITY_COVERED          0.960178              0.103144           0.161680
# METHOD_MISSED               0.021652             -0.792094          -0.443972
# METHOD_COVERED              1.000000              0.088118           0.046861
# Statement_Percentage        0.088118              1.000000           0.634213
# Branch_Percentage           0.046861              0.634213           1.000000
# CC                          0.862600             -0.179181          -0.087616
#
#                             CC
# INSTRUCTION_MISSED    0.610218
# INSTRUCTION_COVERED   0.854028
# BRANCH_MISSED         0.660673
# BRANCH_COVERED        0.801718
# LINE_MISSED           0.596361
# LINE_COVERED          0.854303
# COMPLEXITY_MISSED     0.625108
# COMPLEXITY_COVERED    0.903361
# METHOD_MISSED         0.280353
# METHOD_COVERED        0.862600
# Statement_Percentage -0.179181
# Branch_Percentage    -0.087616
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.179181
# Statement_Percentage -0.179181              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.07707553106620058, pvalue=0.08326277797195603)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.087616
# Branch_Percentage -0.087616           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.08761642614291484, pvalue=0.04886153423957912)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 84.93742761094946

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 73.3567134268537
