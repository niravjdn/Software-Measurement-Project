# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/io/common-io2.6.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-io2.6 (3-Apr-2019 4:59:30 PM)/commons-...
# 1  commons-io2.6 (3-Apr-2019 4:59:30 PM)/commons-...
# 2  commons-io2.6 (3-Apr-2019 4:59:30 PM)/commons-...
# 3  commons-io2.6 (3-Apr-2019 4:59:30 PM)/commons-...
# 4  commons-io2.6 (3-Apr-2019 4:59:30 PM)/commons-...
#
#                                PACKAGE                        CLASS  \
# 0  org.apache.commons.io.serialization         FullClassNameMatcher
# 1  org.apache.commons.io.serialization  ValidatingObjectInputStream
# 2  org.apache.commons.io.serialization     WildcardClassNameMatcher
# 3  org.apache.commons.io.serialization       RegexpClassNameMatcher
# 4        org.apache.commons.io.monitor       FileAlterationObserver
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                   0                   16              0               0
# 1                   6                  223              0              18
# 2                   0                   11              0               0
# 3                   0                   24              0               2
# 4                  48                  514             10              60
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            0             4                  0                   2
# 1            2            36                  0                  21
# 2            0             4                  0                   2
# 3            0             8                  0                   4
# 4           10           113                 11                  47
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0              0               2            100.000000                NaN   2
# 1              0              12             94.736842         100.000000  21
# 2              0               2            100.000000                NaN   2
# 3              0               3            100.000000         100.000000   4
# 4              3              20             91.869919          85.714286  58

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.550539       0.622832
# INSTRUCTION_COVERED             0.550539             1.000000       0.508146
# BRANCH_MISSED                   0.622832             0.508146       1.000000
# BRANCH_COVERED                  0.471588             0.686418       0.671250
# LINE_MISSED                     0.955271             0.471531       0.516856
# LINE_COVERED                    0.579342             0.978800       0.512797
# COMPLEXITY_MISSED               0.708969             0.348467       0.841912
# COMPLEXITY_COVERED              0.517245             0.889382       0.497260
# METHOD_MISSED                   0.529959             0.059713       0.347805
# METHOD_COVERED                  0.516555             0.861240       0.468536
# Statement_Percentage           -0.832400            -0.162299      -0.349275
# Branch_Percentage              -0.627468            -0.189400      -0.894361
# CC                              0.653991             0.862717       0.625354
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.471588     0.955271      0.579342
# INSTRUCTION_COVERED         0.686418     0.471531      0.978800
# BRANCH_MISSED               0.671250     0.516856      0.512797
# BRANCH_COVERED              1.000000     0.386062      0.674712
# LINE_MISSED                 0.386062     1.000000      0.509668
# LINE_COVERED                0.674712     0.509668      1.000000
# COMPLEXITY_MISSED           0.579612     0.650032      0.369514
# COMPLEXITY_COVERED          0.748830     0.465615      0.916636
# METHOD_MISSED               0.265190     0.591665      0.091111
# METHOD_COVERED              0.587027     0.466942      0.900442
# Statement_Percentage       -0.184696    -0.898320     -0.204471
# Branch_Percentage          -0.120198    -0.525785     -0.202718
# CC                          0.782058     0.592686      0.889213
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.708969            0.517245       0.529959
# INSTRUCTION_COVERED            0.348467            0.889382       0.059713
# BRANCH_MISSED                  0.841912            0.497260       0.347805
# BRANCH_COVERED                 0.579612            0.748830       0.265190
# LINE_MISSED                    0.650032            0.465615       0.591665
# LINE_COVERED                   0.369514            0.916636       0.091111
# COMPLEXITY_MISSED              1.000000            0.381574       0.713143
# COMPLEXITY_COVERED             0.381574            1.000000       0.161360
# METHOD_MISSED                  0.713143            0.161360       1.000000
# METHOD_COVERED                 0.345027            0.954949       0.130621
# Statement_Percentage          -0.607309           -0.172950      -0.660621
# Branch_Percentage             -0.820634           -0.076141      -0.314369
# CC                             0.590722            0.947306       0.331950
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.516555             -0.832400          -0.627468
# INSTRUCTION_COVERED         0.861240             -0.162299          -0.189400
# BRANCH_MISSED               0.468536             -0.349275          -0.894361
# BRANCH_COVERED              0.587027             -0.184696          -0.120198
# LINE_MISSED                 0.466942             -0.898320          -0.525785
# LINE_COVERED                0.900442             -0.204471          -0.202718
# COMPLEXITY_MISSED           0.345027             -0.607309          -0.820634
# COMPLEXITY_COVERED          0.954949             -0.172950          -0.076141
# METHOD_MISSED               0.130621             -0.660621          -0.314369
# METHOD_COVERED              1.000000             -0.183452          -0.183322
# Statement_Percentage       -0.183452              1.000000           0.522613
# Branch_Percentage          -0.183322              0.522613           1.000000
# CC                          0.906981             -0.343668          -0.322243
#
#                             CC
# INSTRUCTION_MISSED    0.653991
# INSTRUCTION_COVERED   0.862717
# BRANCH_MISSED         0.625354
# BRANCH_COVERED        0.782058
# LINE_MISSED           0.592686
# LINE_COVERED          0.889213
# COMPLEXITY_MISSED     0.590722
# COMPLEXITY_COVERED    0.947306
# METHOD_MISSED         0.331950
# METHOD_COVERED        0.906981
# Statement_Percentage -0.343668
# Branch_Percentage    -0.322243
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.343668
# Statement_Percentage -0.343668              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.30347293659952984, pvalue=7.808846033692985e-05)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.322243
# Branch_Percentage -0.322243           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.3222427319292438, pvalue=2.5768774181684598e-05)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 89.0759507464313

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 81.48445873526259
