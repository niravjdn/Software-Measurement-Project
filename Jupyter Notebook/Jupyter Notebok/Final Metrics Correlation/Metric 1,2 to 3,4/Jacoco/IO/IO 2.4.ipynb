# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/io/common-io2.4.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-io2.4 (3-Apr-2019 4:51:19 PM)/commons-...
# 1  commons-io2.4 (3-Apr-2019 4:51:19 PM)/commons-...
# 2  commons-io2.4 (3-Apr-2019 4:51:19 PM)/commons-...
# 3  commons-io2.4 (3-Apr-2019 4:51:19 PM)/commons-...
# 4  commons-io2.4 (3-Apr-2019 4:51:19 PM)/commons-...
#
#                          PACKAGE                          CLASS  \
# 0  org.apache.commons.io.monitor          FileAlterationMonitor
# 1  org.apache.commons.io.monitor                      FileEntry
# 2  org.apache.commons.io.monitor         FileAlterationObserver
# 3  org.apache.commons.io.monitor  FileAlterationListenerAdaptor
# 4    org.apache.commons.io.input              BrokenInputStream
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                   5                  179              1              25
# 1                  51                  120              9              13
# 2                  63                  517             12              62
# 3                   0                   11              0               0
# 4                   7                   21              0               0
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            2            51                  1                  24
# 1           16            29                 18                  13
# 2           11           113                 13                  46
# 3            0             9                  0                   9
# 4            2             8                  1                   6
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0              0              12             96.226415          96.153846  25
# 1             10              10             64.444444          59.090909  31
# 2              3              19             91.129032          83.783784  59
# 3              0               9            100.000000                NaN   9
# 4              1               6             80.000000                NaN   7

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.542499       0.584346
# INSTRUCTION_COVERED             0.542499             1.000000       0.474908
# BRANCH_MISSED                   0.584346             0.474908       1.000000
# BRANCH_COVERED                  0.377091             0.654186       0.638375
# LINE_MISSED                     0.942526             0.457876       0.445730
# LINE_COVERED                    0.576538             0.983102       0.471831
# COMPLEXITY_MISSED               0.649532             0.361726       0.886400
# COMPLEXITY_COVERED              0.483653             0.888635       0.460732
# METHOD_MISSED                   0.467807             0.047198       0.362073
# METHOD_COVERED                  0.492435             0.857205       0.420185
# Statement_Percentage           -0.843302            -0.180729      -0.324458
# Branch_Percentage              -0.574855            -0.117903      -0.858927
# CC                              0.606739             0.859508       0.601450
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.377091     0.942526      0.576538
# INSTRUCTION_COVERED         0.654186     0.457876      0.983102
# BRANCH_MISSED               0.638375     0.445730      0.471831
# BRANCH_COVERED              1.000000     0.290968      0.625717
# LINE_MISSED                 0.290968     1.000000      0.503813
# LINE_COVERED                0.625717     0.503813      1.000000
# COMPLEXITY_MISSED           0.592905     0.548198      0.372401
# COMPLEXITY_COVERED          0.741329     0.447441      0.903697
# METHOD_MISSED               0.295658     0.529443      0.079336
# METHOD_COVERED              0.547970     0.456620      0.891029
# Statement_Percentage       -0.140147    -0.911477     -0.230906
# Branch_Percentage           0.013691    -0.426323     -0.126226
# CC                          0.777682     0.548188      0.875034
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.649532            0.483653       0.467807
# INSTRUCTION_COVERED            0.361726            0.888635       0.047198
# BRANCH_MISSED                  0.886400            0.460732       0.362073
# BRANCH_COVERED                 0.592905            0.741329       0.295658
# LINE_MISSED                    0.548198            0.447441       0.529443
# LINE_COVERED                   0.372401            0.903697       0.079336
# COMPLEXITY_MISSED              1.000000            0.395532       0.657821
# COMPLEXITY_COVERED             0.395532            1.000000       0.178083
# METHOD_MISSED                  0.657821            0.178083       1.000000
# METHOD_COVERED                 0.341727            0.941161       0.127716
# Statement_Percentage          -0.505747           -0.195705      -0.590509
# Branch_Percentage             -0.778554            0.022458      -0.250941
# CC                             0.594063            0.951790       0.339677
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.492435             -0.843302          -0.574855
# INSTRUCTION_COVERED         0.857205             -0.180729          -0.117903
# BRANCH_MISSED               0.420185             -0.324458          -0.858927
# BRANCH_COVERED              0.547970             -0.140147           0.013691
# LINE_MISSED                 0.456620             -0.911477          -0.426323
# LINE_COVERED                0.891029             -0.230906          -0.126226
# COMPLEXITY_MISSED           0.341727             -0.505747          -0.778554
# COMPLEXITY_COVERED          0.941161             -0.195705           0.022458
# METHOD_MISSED               0.127716             -0.590509          -0.250941
# METHOD_COVERED              1.000000             -0.209693          -0.086478
# Statement_Percentage       -0.209693              1.000000           0.425458
# Branch_Percentage          -0.086478              0.425458           1.000000
# CC                          0.895578             -0.324699          -0.203899
#
#                             CC
# INSTRUCTION_MISSED    0.606739
# INSTRUCTION_COVERED   0.859508
# BRANCH_MISSED         0.601450
# BRANCH_COVERED        0.777682
# LINE_MISSED           0.548188
# LINE_COVERED          0.875034
# COMPLEXITY_MISSED     0.594063
# COMPLEXITY_COVERED    0.951790
# METHOD_MISSED         0.339677
# METHOD_COVERED        0.895578
# Statement_Percentage -0.324699
# Branch_Percentage    -0.203899
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.324699
# Statement_Percentage -0.324699              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.2927641582877547, pvalue=0.00030516312329249633)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.203899
# Branch_Percentage -0.203899           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.20389906424709917, pvalue=0.012930507869229675)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 89.22454064154469

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 82.0221266133989
