# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/io/common-io2.5.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-io2.5 (3-Apr-2019 4:55:17 PM)/commons-...
# 1  commons-io2.5 (3-Apr-2019 4:55:17 PM)/commons-...
# 2  commons-io2.5 (3-Apr-2019 4:55:17 PM)/commons-...
# 3  commons-io2.5 (3-Apr-2019 4:55:17 PM)/commons-...
# 4  commons-io2.5 (3-Apr-2019 4:55:17 PM)/commons-...
#
#                                PACKAGE                        CLASS  \
# 0  org.apache.commons.io.serialization  ValidatingObjectInputStream
# 1  org.apache.commons.io.serialization         FullClassNameMatcher
# 2  org.apache.commons.io.serialization     WildcardClassNameMatcher
# 3  org.apache.commons.io.serialization       RegexpClassNameMatcher
# 4        org.apache.commons.io.monitor       FileAlterationObserver
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                   6                  223              0              18
# 1                   0                   16              0               0
# 2                   0                   11              0               0
# 3                   0                   24              0               2
# 4                  48                  514             10              60
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            2            36                  0                  21
# 1            0             4                  0                   2
# 2            0             4                  0                   2
# 3            0             8                  0                   4
# 4           10           113                 11                  47
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0              0              12             94.736842         100.000000  21
# 1              0               2            100.000000                NaN   2
# 2              0               2            100.000000                NaN   2
# 3              0               3            100.000000         100.000000   4
# 4              3              20             91.869919          85.714286  58

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.558085       0.629981
# INSTRUCTION_COVERED             0.558085             1.000000       0.503305
# BRANCH_MISSED                   0.629981             0.503305       1.000000
# BRANCH_COVERED                  0.444882             0.677973       0.650697
# LINE_MISSED                     0.957355             0.482210       0.523693
# LINE_COVERED                    0.584620             0.979792       0.505702
# COMPLEXITY_MISSED               0.699011             0.347987       0.853820
# COMPLEXITY_COVERED              0.494310             0.897471       0.474790
# METHOD_MISSED                   0.515613             0.050215       0.371647
# METHOD_COVERED                  0.489429             0.872240       0.445060
# Statement_Percentage           -0.832191            -0.164307      -0.358815
# Branch_Percentage              -0.650921            -0.161557      -0.882284
# CC                              0.638606             0.870634       0.615555
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.444882     0.957355      0.584620
# INSTRUCTION_COVERED         0.677973     0.482210      0.979792
# BRANCH_MISSED               0.650697     0.523693      0.505702
# BRANCH_COVERED              1.000000     0.363058      0.665100
# LINE_MISSED                 0.363058     1.000000      0.516178
# LINE_COVERED                0.665100     0.516178      1.000000
# COMPLEXITY_MISSED           0.564284     0.637872      0.360540
# COMPLEXITY_COVERED          0.748878     0.445070      0.918633
# METHOD_MISSED               0.261154     0.575214      0.069451
# METHOD_COVERED              0.588507     0.443650      0.904699
# Statement_Percentage       -0.168343    -0.894630     -0.200855
# Branch_Percentage          -0.034938    -0.547176     -0.175021
# CC                          0.783186     0.580958      0.891074
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.699011            0.494310       0.515613
# INSTRUCTION_COVERED            0.347987            0.897471       0.050215
# BRANCH_MISSED                  0.853820            0.474790       0.371647
# BRANCH_COVERED                 0.564284            0.748878       0.261154
# LINE_MISSED                    0.637872            0.445070       0.575214
# LINE_COVERED                   0.360540            0.918633       0.069451
# COMPLEXITY_MISSED              1.000000            0.352657       0.715564
# COMPLEXITY_COVERED             0.352657            1.000000       0.115600
# METHOD_MISSED                  0.715564            0.115600       1.000000
# METHOD_COVERED                 0.309441            0.956534       0.072141
# Statement_Percentage          -0.596872           -0.144168      -0.656455
# Branch_Percentage             -0.817822           -0.002403      -0.340012
# CC                             0.574278            0.944440       0.310486
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.489429             -0.832191          -0.650921
# INSTRUCTION_COVERED         0.872240             -0.164307          -0.161557
# BRANCH_MISSED               0.445060             -0.358815          -0.882284
# BRANCH_COVERED              0.588507             -0.168343          -0.034938
# LINE_MISSED                 0.443650             -0.894630          -0.547176
# LINE_COVERED                0.904699             -0.200855          -0.175021
# COMPLEXITY_MISSED           0.309441             -0.596872          -0.817822
# COMPLEXITY_COVERED          0.956534             -0.144168          -0.002403
# METHOD_MISSED               0.072141             -0.656455          -0.340012
# METHOD_COVERED              1.000000             -0.147839          -0.118452
# Statement_Percentage       -0.147839              1.000000           0.545106
# Branch_Percentage          -0.118452              0.545106           1.000000
# CC                          0.899994             -0.325063          -0.262734
#
#                             CC
# INSTRUCTION_MISSED    0.638606
# INSTRUCTION_COVERED   0.870634
# BRANCH_MISSED         0.615555
# BRANCH_COVERED        0.783186
# LINE_MISSED           0.580958
# LINE_COVERED          0.891074
# COMPLEXITY_MISSED     0.574278
# COMPLEXITY_COVERED    0.944440
# METHOD_MISSED         0.310486
# METHOD_COVERED        0.899994
# Statement_Percentage -0.325063
# Branch_Percentage    -0.262734
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.325063
# Statement_Percentage -0.325063              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.25064378050437286, pvalue=0.0012954733147129865)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.262734
# Branch_Percentage -0.262734           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.26273449977724017, pvalue=0.0007309225556964671)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 88.65587308486363

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 80.85106382978722
