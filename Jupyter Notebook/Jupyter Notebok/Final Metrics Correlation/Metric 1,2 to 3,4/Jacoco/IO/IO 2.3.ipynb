# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/io/common-io2.3.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-io2.3 (3-Apr-2019 4:46:29 PM)/commons-...
# 1  commons-io2.3 (3-Apr-2019 4:46:29 PM)/commons-...
# 2  commons-io2.3 (3-Apr-2019 4:46:29 PM)/commons-...
# 3  commons-io2.3 (3-Apr-2019 4:46:29 PM)/commons-...
# 4  commons-io2.3 (3-Apr-2019 4:46:29 PM)/commons-...
#
#                          PACKAGE                          CLASS  \
# 0  org.apache.commons.io.monitor  FileAlterationListenerAdaptor
# 1  org.apache.commons.io.monitor         FileAlterationObserver
# 2  org.apache.commons.io.monitor                      FileEntry
# 3  org.apache.commons.io.monitor          FileAlterationMonitor
# 4    org.apache.commons.io.input              ReaderInputStream
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                   0                   11              0               0
# 1                  63                  517             12              62
# 2                  51                  120              9              13
# 3                   5                  179              1              25
# 4                  38                  221              7              29
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            0             9                  0                   9
# 1           11           113                 13                  46
# 2           16            29                 18                  13
# 3            2            51                  1                  24
# 4            6            59                  9                  21
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0              0               9            100.000000                NaN   9
# 1              3              19             91.129032          83.783784  59
# 2             10              10             64.444444          59.090909  31
# 3              0              12             96.226415          96.153846  25
# 4              2              10             90.769231          80.555556  30

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.543622       0.582243
# INSTRUCTION_COVERED             0.543622             1.000000       0.471243
# BRANCH_MISSED                   0.582243             0.471243       1.000000
# BRANCH_COVERED                  0.375395             0.652931       0.639271
# LINE_MISSED                     0.945162             0.464848       0.451558
# LINE_COVERED                    0.579644             0.982931       0.470000
# COMPLEXITY_MISSED               0.657390             0.368969       0.882176
# COMPLEXITY_COVERED              0.482894             0.885812       0.457427
# METHOD_MISSED                   0.477002             0.059474       0.354809
# METHOD_COVERED                  0.492122             0.854076       0.414782
# Statement_Percentage           -0.844349            -0.184173      -0.327858
# Branch_Percentage              -0.573304            -0.110444      -0.856684
# CC                              0.607045             0.856385       0.600414
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.375395     0.945162      0.579644
# INSTRUCTION_COVERED         0.652931     0.464848      0.982931
# BRANCH_MISSED               0.639271     0.451558      0.470000
# BRANCH_COVERED              1.000000     0.295802      0.623894
# LINE_MISSED                 0.295802     1.000000      0.513319
# LINE_COVERED                0.623894     0.513319      1.000000
# COMPLEXITY_MISSED           0.585886     0.562796      0.381193
# COMPLEXITY_COVERED          0.741531     0.451352      0.900883
# METHOD_MISSED               0.283825     0.538092      0.092937
# METHOD_COVERED              0.547772     0.460855      0.888649
# Statement_Percentage       -0.143123    -0.910484     -0.236708
# Branch_Percentage           0.020199    -0.429271     -0.122422
# CC                          0.779539     0.554005      0.872248
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.657390            0.482894       0.477002
# INSTRUCTION_COVERED            0.368969            0.885812       0.059474
# BRANCH_MISSED                  0.882176            0.457427       0.354809
# BRANCH_COVERED                 0.585886            0.741531       0.283825
# LINE_MISSED                    0.562796            0.451352       0.538092
# LINE_COVERED                   0.381193            0.900883       0.092937
# COMPLEXITY_MISSED              1.000000            0.400365       0.658787
# COMPLEXITY_COVERED             0.400365            1.000000       0.187465
# METHOD_MISSED                  0.658787            0.187465       1.000000
# METHOD_COVERED                 0.346932            0.940392       0.139379
# Statement_Percentage          -0.513286           -0.198508      -0.592543
# Branch_Percentage             -0.778762            0.035561      -0.250844
# CC                             0.600947            0.951165       0.350036
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.492122             -0.844349          -0.573304
# INSTRUCTION_COVERED         0.854076             -0.184173          -0.110444
# BRANCH_MISSED               0.414782             -0.327858          -0.856684
# BRANCH_COVERED              0.547772             -0.143123           0.020199
# LINE_MISSED                 0.460855             -0.910484          -0.429271
# LINE_COVERED                0.888649             -0.236708          -0.122422
# COMPLEXITY_MISSED           0.346932             -0.513286          -0.778762
# COMPLEXITY_COVERED          0.940392             -0.198508           0.035561
# METHOD_MISSED               0.139379             -0.592543          -0.250844
# METHOD_COVERED              1.000000             -0.212343          -0.074064
# Statement_Percentage       -0.212343              1.000000           0.424290
# Branch_Percentage          -0.074064              0.424290           1.000000
# CC                          0.893478             -0.329316          -0.194506
#
#                             CC
# INSTRUCTION_MISSED    0.607045
# INSTRUCTION_COVERED   0.856385
# BRANCH_MISSED         0.600414
# BRANCH_COVERED        0.779539
# LINE_MISSED           0.554005
# LINE_COVERED          0.872248
# COMPLEXITY_MISSED     0.600947
# COMPLEXITY_COVERED    0.951165
# METHOD_MISSED         0.350036
# METHOD_COVERED        0.893478
# Statement_Percentage -0.329316
# Branch_Percentage    -0.194506
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.329316
# Statement_Percentage -0.329316              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.29139237581988087, pvalue=0.00034252588779988866)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.194506
# Branch_Percentage -0.194506           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.19450613223877733, pvalue=0.01823940428318914)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 88.99327155008253

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 81.80661577608143
