# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/io/common-io2.2.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-io2.2 (3-Apr-2019 4:41:41 PM)/commons-...
# 1  commons-io2.2 (3-Apr-2019 4:41:41 PM)/commons-...
# 2  commons-io2.2 (3-Apr-2019 4:41:41 PM)/commons-...
# 3  commons-io2.2 (3-Apr-2019 4:41:41 PM)/commons-...
# 4  commons-io2.2 (3-Apr-2019 4:41:41 PM)/commons-...
#
#                          PACKAGE                          CLASS  \
# 0  org.apache.commons.io.monitor                      FileEntry
# 1  org.apache.commons.io.monitor  FileAlterationListenerAdaptor
# 2  org.apache.commons.io.monitor         FileAlterationObserver
# 3  org.apache.commons.io.monitor          FileAlterationMonitor
# 4    org.apache.commons.io.input              TaggedInputStream
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                  51                  120              9              13
# 1                   0                   11              0               0
# 2                  63                  517             12              62
# 3                   4                  180              0              26
# 4                   0                   24              0               0
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0           16            29                 18                  13
# 1            0             9                  0                   9
# 2           11           113                 13                  46
# 3            1            52                  0                  25
# 4            0             7                  0                   4
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0             10              10             64.444444          59.090909  31
# 1              0               9            100.000000                NaN   9
# 2              3              19             91.129032          83.783784  59
# 3              0              12             98.113208         100.000000  25
# 4              0               4            100.000000                NaN   4

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.542983       0.585211
# INSTRUCTION_COVERED             0.542983             1.000000       0.466654
# BRANCH_MISSED                   0.585211             0.466654       1.000000
# BRANCH_COVERED                  0.376979             0.653590       0.631770
# LINE_MISSED                     0.945273             0.463220       0.452886
# LINE_COVERED                    0.581149             0.982727       0.464809
# COMPLEXITY_MISSED               0.647294             0.355002       0.889621
# COMPLEXITY_COVERED              0.482921             0.885551       0.449500
# METHOD_MISSED                   0.465682             0.044792       0.371608
# METHOD_COVERED                  0.493101             0.852612       0.408924
# Statement_Percentage           -0.844748            -0.184029      -0.331552
# Branch_Percentage              -0.572539            -0.102868      -0.855705
# CC                              0.607111             0.855733       0.593762
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.376979     0.945273      0.581149
# INSTRUCTION_COVERED         0.653590     0.463220      0.982727
# BRANCH_MISSED               0.631770     0.452886      0.464809
# BRANCH_COVERED              1.000000     0.295575      0.626189
# LINE_MISSED                 0.295575     1.000000      0.514161
# LINE_COVERED                0.626189     0.514161      1.000000
# COMPLEXITY_MISSED           0.583768     0.552274      0.367766
# COMPLEXITY_COVERED          0.744256     0.449864      0.900608
# METHOD_MISSED               0.295028     0.528760      0.081859
# METHOD_COVERED              0.550049     0.460857      0.886981
# Statement_Percentage       -0.143795    -0.911360     -0.239576
# Branch_Percentage           0.031491    -0.429510     -0.114080
# CC                          0.782292     0.552889      0.872421
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.647294            0.482921       0.465682
# INSTRUCTION_COVERED            0.355002            0.885551       0.044792
# BRANCH_MISSED                  0.889621            0.449500       0.371608
# BRANCH_COVERED                 0.583768            0.744256       0.295028
# LINE_MISSED                    0.552274            0.449864       0.528760
# LINE_COVERED                   0.367766            0.900608       0.081859
# COMPLEXITY_MISSED              1.000000            0.384746       0.659041
# COMPLEXITY_COVERED             0.384746            1.000000       0.177762
# METHOD_MISSED                  0.659041            0.177762       1.000000
# METHOD_COVERED                 0.331829            0.938381       0.126493
# Statement_Percentage          -0.508815           -0.199087      -0.591222
# Branch_Percentage             -0.781622            0.048503      -0.263603
# CC                             0.587047            0.951630       0.341605
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.493101             -0.844748          -0.572539
# INSTRUCTION_COVERED         0.852612             -0.184029          -0.102868
# BRANCH_MISSED               0.408924             -0.331552          -0.855705
# BRANCH_COVERED              0.550049             -0.143795           0.031491
# LINE_MISSED                 0.460857             -0.911360          -0.429510
# LINE_COVERED                0.886981             -0.239576          -0.114080
# COMPLEXITY_MISSED           0.331829             -0.508815          -0.781622
# COMPLEXITY_COVERED          0.938381             -0.199087           0.048503
# METHOD_MISSED               0.126493             -0.591222          -0.263603
# METHOD_COVERED              1.000000             -0.215016          -0.064036
# Statement_Percentage       -0.215016              1.000000           0.429335
# Branch_Percentage          -0.064036              0.429335           1.000000
# CC                          0.892301             -0.329891          -0.182039
#
#                             CC
# INSTRUCTION_MISSED    0.607111
# INSTRUCTION_COVERED   0.855733
# BRANCH_MISSED         0.593762
# BRANCH_COVERED        0.782292
# LINE_MISSED           0.552889
# LINE_COVERED          0.872421
# COMPLEXITY_MISSED     0.587047
# COMPLEXITY_COVERED    0.951630
# METHOD_MISSED         0.341605
# METHOD_COVERED        0.892301
# Statement_Percentage -0.329891
# Branch_Percentage    -0.182039
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.329891
# Statement_Percentage -0.329891              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.29962201709982406, pvalue=0.00023878005658777756)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.182039
# Branch_Percentage -0.182039           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.18203940220978307, pvalue=0.02787136840577062)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 89.09774436090225

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 81.80389692017599
