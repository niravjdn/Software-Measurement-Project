# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/collection/collections-v4.2.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-collections4 (Apr 2, 2019 8:21:36 PM)/...
# 1  commons-collections4 (Apr 2, 2019 8:21:36 PM)/...
# 2  commons-collections4 (Apr 2, 2019 8:21:36 PM)/...
# 3  commons-collections4 (Apr 2, 2019 8:21:36 PM)/...
# 4  commons-collections4 (Apr 2, 2019 8:21:36 PM)/...
#
#                                     PACKAGE                            CLASS  \
# 0  org.apache.commons.collections4.splitmap              TransformedSplitMap
# 1  org.apache.commons.collections4.splitmap  AbstractIterableGetMapDecorator
# 2  org.apache.commons.collections4.keyvalue                         MultiKey
# 3  org.apache.commons.collections4.keyvalue                  DefaultKeyValue
# 4  org.apache.commons.collections4.keyvalue                 AbstractMapEntry
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                  24                   94              3               5
# 1                  22                   61              2               2
# 2                   0                  190              0              12
# 3                   4                  110              5              19
# 4                   0                   70              1              19
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            7            22                  5                  10
# 1            5            18                  5                  13
# 2            0            38                  0                  20
# 3            1            24                  5                  16
# 4            0            13                  1                  13
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0              2               9             75.862069          62.500000  15
# 1              3              13             78.260870          50.000000  18
# 2              0              14            100.000000         100.000000  20
# 3              0               9             96.000000          79.166667  21
# 4              0               4            100.000000          95.000000  14

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.449294       0.638052
# INSTRUCTION_COVERED             0.449294             1.000000       0.490340
# BRANCH_MISSED                   0.638052             0.490340       1.000000
# BRANCH_COVERED                  0.382072             0.745816       0.614685
# LINE_MISSED                     0.971839             0.424590       0.572726
# LINE_COVERED                    0.469971             0.978327       0.481137
# COMPLEXITY_MISSED               0.822017             0.363920       0.793422
# COMPLEXITY_COVERED              0.403122             0.916119       0.437206
# METHOD_MISSED                   0.607506            -0.017298       0.211073
# METHOD_COVERED                  0.397960             0.861425       0.370630
# Statement_Percentage           -0.841749            -0.071946      -0.379614
# Branch_Percentage              -0.597297            -0.049037      -0.840836
# CC                              0.591800             0.875778       0.594006
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.382072     0.971839      0.469971
# INSTRUCTION_COVERED         0.745816     0.424590      0.978327
# BRANCH_MISSED               0.614685     0.572726      0.481137
# BRANCH_COVERED              1.000000     0.344805      0.714728
# LINE_MISSED                 0.344805     1.000000      0.447951
# LINE_COVERED                0.714728     0.447951      1.000000
# COMPLEXITY_MISSED           0.492118     0.778536      0.363432
# COMPLEXITY_COVERED          0.738489     0.385552      0.925683
# METHOD_MISSED               0.064496     0.624554     -0.005138
# METHOD_COVERED              0.548541     0.381029      0.885912
# Statement_Percentage       -0.086112    -0.871283     -0.092482
# Branch_Percentage           0.040692    -0.533253     -0.066233
# CC                          0.748923     0.566325      0.885307
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.822017            0.403122       0.607506
# INSTRUCTION_COVERED            0.363920            0.916119      -0.017298
# BRANCH_MISSED                  0.793422            0.437206       0.211073
# BRANCH_COVERED                 0.492118            0.738489       0.064496
# LINE_MISSED                    0.778536            0.385552       0.624554
# LINE_COVERED                   0.363432            0.925683      -0.005138
# COMPLEXITY_MISSED              1.000000            0.361360       0.671667
# COMPLEXITY_COVERED             0.361360            1.000000       0.051962
# METHOD_MISSED                  0.671667            0.051962       1.000000
# METHOD_COVERED                 0.314977            0.949298       0.050587
# Statement_Percentage          -0.714421           -0.052911      -0.747355
# Branch_Percentage             -0.699178            0.055290      -0.230105
# CC                             0.586587            0.944470       0.242895
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.397960             -0.841749          -0.597297
# INSTRUCTION_COVERED         0.861425             -0.071946          -0.049037
# BRANCH_MISSED               0.370630             -0.379614          -0.840836
# BRANCH_COVERED              0.548541             -0.086112           0.040692
# LINE_MISSED                 0.381029             -0.871283          -0.533253
# LINE_COVERED                0.885912             -0.092482          -0.066233
# COMPLEXITY_MISSED           0.314977             -0.714421          -0.699178
# COMPLEXITY_COVERED          0.949298             -0.052911           0.055290
# METHOD_MISSED               0.050587             -0.747355          -0.230105
# METHOD_COVERED              1.000000             -0.054551          -0.038711
# Statement_Percentage       -0.054551              1.000000           0.565219
# Branch_Percentage          -0.038711              0.565219           1.000000
# CC                          0.893146             -0.268906          -0.181132
#
#                             CC
# INSTRUCTION_MISSED    0.591800
# INSTRUCTION_COVERED   0.875778
# BRANCH_MISSED         0.594006
# BRANCH_COVERED        0.748923
# LINE_MISSED           0.566325
# LINE_COVERED          0.885307
# COMPLEXITY_MISSED     0.586587
# COMPLEXITY_COVERED    0.944470
# METHOD_MISSED         0.242895
# METHOD_COVERED        0.893146
# Statement_Percentage -0.268906
# Branch_Percentage    -0.181132
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.268906
# Statement_Percentage -0.268906              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.21101544784359044, pvalue=1.261685526769464e-06)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.181132
# Branch_Percentage -0.181132           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.18113170154229663, pvalue=3.3703860682684945e-05)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 88.8383641131507

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 78.79982479194044
