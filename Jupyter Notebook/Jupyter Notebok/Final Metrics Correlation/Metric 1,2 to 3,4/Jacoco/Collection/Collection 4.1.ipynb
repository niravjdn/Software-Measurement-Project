# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/collection/collections-v4.1.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-collections4 (Apr 2, 2019 8:25:51 PM)/...
# 1  commons-collections4 (Apr 2, 2019 8:25:51 PM)/...
# 2  commons-collections4 (Apr 2, 2019 8:25:51 PM)/...
# 3  commons-collections4 (Apr 2, 2019 8:25:51 PM)/...
# 4  commons-collections4 (Apr 2, 2019 8:25:51 PM)/...
#
#                                     PACKAGE                      CLASS  \
# 0  org.apache.commons.collections4.keyvalue       UnmodifiableMapEntry
# 1  org.apache.commons.collections4.keyvalue           AbstractKeyValue
# 2  org.apache.commons.collections4.keyvalue           AbstractMapEntry
# 3  org.apache.commons.collections4.keyvalue            DefaultKeyValue
# 4  org.apache.commons.collections4.keyvalue  AbstractMapEntryDecorator
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                   0                   24              0               0
# 1                   0                   44              0               0
# 2                   0                   70              1              19
# 3                   4                  110              5              19
# 4                  11                   36              2               2
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            0             7                  0                   4
# 1            0            17                  0                   6
# 2            0            13                  1                  13
# 3            1            24                  5                  16
# 4            3            11                  3                   7
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0              0               4            100.000000                NaN   4
# 1              0               6            100.000000                NaN   6
# 2              0               4            100.000000          95.000000  14
# 3              0               9             96.000000          79.166667  21
# 4              1               7             78.571429          50.000000  10

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.450395       0.634880
# INSTRUCTION_COVERED             0.450395             1.000000       0.497829
# BRANCH_MISSED                   0.634880             0.497829       1.000000
# BRANCH_COVERED                  0.385220             0.749082       0.619994
# LINE_MISSED                     0.971301             0.422699       0.567473
# LINE_COVERED                    0.471794             0.978598       0.488017
# COMPLEXITY_MISSED               0.820269             0.360870       0.789716
# COMPLEXITY_COVERED              0.405032             0.915835       0.445102
# METHOD_MISSED                   0.607369            -0.025508       0.208132
# METHOD_COVERED                  0.399459             0.861442       0.377808
# Statement_Percentage           -0.838758            -0.065416      -0.373769
# Branch_Percentage              -0.596088            -0.062061      -0.843620
# CC                              0.592850             0.875687       0.596649
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.385220     0.971301      0.471794
# INSTRUCTION_COVERED         0.749082     0.422699      0.978598
# BRANCH_MISSED               0.619994     0.567473      0.488017
# BRANCH_COVERED              1.000000     0.345340      0.719165
# LINE_MISSED                 0.345340     1.000000      0.447102
# LINE_COVERED                0.719165     0.447102      1.000000
# COMPLEXITY_MISSED           0.488933     0.776135      0.360507
# COMPLEXITY_COVERED          0.742301     0.384687      0.925547
# METHOD_MISSED               0.061202     0.624608     -0.012644
# METHOD_COVERED              0.552719     0.379857      0.885586
# Statement_Percentage       -0.083126    -0.869556     -0.086948
# Branch_Percentage           0.028303    -0.532473     -0.077202
# CC                          0.751885     0.564808      0.885196
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.820269            0.405032       0.607369
# INSTRUCTION_COVERED            0.360870            0.915835      -0.025508
# BRANCH_MISSED                  0.789716            0.445102       0.208132
# BRANCH_COVERED                 0.488933            0.742301       0.061202
# LINE_MISSED                    0.776135            0.384687       0.624608
# LINE_COVERED                   0.360507            0.925547      -0.012644
# COMPLEXITY_MISSED              1.000000            0.358730       0.673685
# COMPLEXITY_COVERED             0.358730            1.000000       0.045364
# METHOD_MISSED                  0.673685            0.045364       1.000000
# METHOD_COVERED                 0.312106            0.948922       0.043215
# Statement_Percentage          -0.715052           -0.048201      -0.752157
# Branch_Percentage             -0.702319            0.043798      -0.237051
# CC                             0.582875            0.944999       0.237413
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.399459             -0.838758          -0.596088
# INSTRUCTION_COVERED         0.861442             -0.065416          -0.062061
# BRANCH_MISSED               0.377808             -0.373769          -0.843620
# BRANCH_COVERED              0.552719             -0.083126           0.028303
# LINE_MISSED                 0.379857             -0.869556          -0.532473
# LINE_COVERED                0.885586             -0.086948          -0.077202
# COMPLEXITY_MISSED           0.312106             -0.715052          -0.702319
# COMPLEXITY_COVERED          0.948922             -0.048201           0.043798
# METHOD_MISSED               0.043215             -0.752157          -0.237051
# METHOD_COVERED              1.000000             -0.049897          -0.051248
# Statement_Percentage       -0.049897              1.000000           0.565788
# Branch_Percentage          -0.051248              0.565788           1.000000
# CC                          0.893631             -0.262993          -0.188280
#
#                             CC
# INSTRUCTION_MISSED    0.592850
# INSTRUCTION_COVERED   0.875687
# BRANCH_MISSED         0.596649
# BRANCH_COVERED        0.751885
# LINE_MISSED           0.564808
# LINE_COVERED          0.885196
# COMPLEXITY_MISSED     0.582875
# COMPLEXITY_COVERED    0.944999
# METHOD_MISSED         0.237413
# METHOD_COVERED        0.893631
# Statement_Percentage -0.262993
# Branch_Percentage    -0.188280
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.262993
# Statement_Percentage -0.262993              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.21661096486775624, pvalue=7.678105036632606e-07)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                         CC  Branch_Percentage
# CC                 1.00000           -0.18828
# Branch_Percentage -0.18828            1.00000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.18827999346445914, pvalue=1.834986509885606e-05)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 87.90223916692747

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 76.91117984975696
