# %%
import pandas as pd
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoc-by-version/collection/collections-v4.0.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                                                GROUP  \
# 0  commons-collections4 (Apr 2, 2019 8:31:09 PM)/...
# 1  commons-collections4 (Apr 2, 2019 8:31:09 PM)/...
# 2  commons-collections4 (Apr 2, 2019 8:31:09 PM)/...
# 3  commons-collections4 (Apr 2, 2019 8:31:09 PM)/...
# 4  commons-collections4 (Apr 2, 2019 8:31:09 PM)/...
#
#                                     PACKAGE                      CLASS  \
# 0  org.apache.commons.collections4.keyvalue               TiedMapEntry
# 1  org.apache.commons.collections4.keyvalue           AbstractKeyValue
# 2  org.apache.commons.collections4.keyvalue  AbstractMapEntryDecorator
# 3  org.apache.commons.collections4.keyvalue           AbstractMapEntry
# 4  org.apache.commons.collections4.keyvalue                   MultiKey
#
#    INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 0                   4                  105              5              17
# 1                   0                   44              0               0
# 2                  11                   36              2               2
# 3                   2                   68              3              17
# 4                   0                  190              0              12
#
#    LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 0            1            21                  5                  13
# 1            0            17                  0                   6
# 2            3            11                  3                   7
# 3            1            12                  3                  11
# 4            0            38                  0                  20
#
#    METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0              0               7             95.454545          77.272727  18
# 1              0               6            100.000000                NaN   6
# 2              1               7             78.571429          50.000000  10
# 3              0               4             92.307692          85.000000  14
# 4              0              14            100.000000         100.000000  20

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.417417       0.639088
# INSTRUCTION_COVERED             0.417417             1.000000       0.506674
# BRANCH_MISSED                   0.639088             0.506674       1.000000
# BRANCH_COVERED                  0.387399             0.759218       0.640152
# LINE_MISSED                     0.975750             0.398434       0.588683
# LINE_COVERED                    0.438757             0.980753       0.496358
# COMPLEXITY_MISSED               0.818737             0.352764       0.803888
# COMPLEXITY_COVERED              0.368049             0.910510       0.454768
# METHOD_MISSED                   0.608244            -0.058303       0.206320
# METHOD_COVERED                  0.355512             0.848142       0.384267
# Statement_Percentage           -0.837630            -0.022317      -0.374181
# Branch_Percentage              -0.601222            -0.048300      -0.830620
# CC                              0.562504             0.867916       0.617940
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.387399     0.975750      0.438757
# INSTRUCTION_COVERED         0.759218     0.398434      0.980753
# BRANCH_MISSED               0.640152     0.588683      0.496358
# BRANCH_COVERED              1.000000     0.355060      0.733646
# LINE_MISSED                 0.355060     1.000000      0.420934
# LINE_COVERED                0.733646     0.420934      1.000000
# COMPLEXITY_MISSED           0.500432     0.784385      0.350445
# COMPLEXITY_COVERED          0.744453     0.353773      0.923952
# METHOD_MISSED               0.048446     0.619841     -0.044904
# METHOD_COVERED              0.544472     0.341602      0.876161
# Statement_Percentage       -0.072134    -0.859685     -0.040170
# Branch_Percentage           0.042949    -0.555136     -0.058430
# CC                          0.759105     0.542806      0.880330
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.818737            0.368049       0.608244
# INSTRUCTION_COVERED            0.352764            0.910510      -0.058303
# BRANCH_MISSED                  0.803888            0.454768       0.206320
# BRANCH_COVERED                 0.500432            0.744453       0.048446
# LINE_MISSED                    0.784385            0.353773       0.619841
# LINE_COVERED                   0.350445            0.923952      -0.044904
# COMPLEXITY_MISSED              1.000000            0.345533       0.658317
# COMPLEXITY_COVERED             0.345533            1.000000       0.006777
# METHOD_MISSED                  0.658317            0.006777       1.000000
# METHOD_COVERED                 0.290586            0.943623      -0.001741
# Statement_Percentage          -0.706369           -0.000173      -0.751349
# Branch_Percentage             -0.718167            0.052191      -0.260488
# CC                             0.577818            0.940199       0.204510
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.355512             -0.837630          -0.601222
# INSTRUCTION_COVERED         0.848142             -0.022317          -0.048300
# BRANCH_MISSED               0.384267             -0.374181          -0.830620
# BRANCH_COVERED              0.544472             -0.072134           0.042949
# LINE_MISSED                 0.341602             -0.859685          -0.555136
# LINE_COVERED                0.876161             -0.040170          -0.058430
# COMPLEXITY_MISSED           0.290586             -0.706369          -0.718167
# COMPLEXITY_COVERED          0.943623             -0.000173           0.052191
# METHOD_MISSED              -0.001741             -0.751349          -0.260488
# METHOD_COVERED              1.000000              0.003487          -0.062321
# Statement_Percentage        0.003487              1.000000           0.596938
# Branch_Percentage          -0.062321              0.596938           1.000000
# CC                          0.882433             -0.219983          -0.199876
#
#                             CC
# INSTRUCTION_MISSED    0.562504
# INSTRUCTION_COVERED   0.867916
# BRANCH_MISSED         0.617940
# BRANCH_COVERED        0.759105
# LINE_MISSED           0.542806
# LINE_COVERED          0.880330
# COMPLEXITY_MISSED     0.577818
# COMPLEXITY_COVERED    0.940199
# METHOD_MISSED         0.204510
# METHOD_COVERED        0.882433
# Statement_Percentage -0.219983
# Branch_Percentage    -0.199876
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.219983
# Statement_Percentage -0.219983              1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Statement_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.18982617456468043, pvalue=7.761207708699311e-05)

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.199876
# Branch_Percentage -0.199876           1.000000

# %%
df_clean = df_collection.dropna()
stats.spearmanr(df_clean['Branch_Percentage'], df_clean['CC'])
# Out:
# SpearmanrResult(correlation=-0.1998762213780474, pvalue=3.112416158097397e-05)

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 87.80383514784725

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 76.21037109855001
