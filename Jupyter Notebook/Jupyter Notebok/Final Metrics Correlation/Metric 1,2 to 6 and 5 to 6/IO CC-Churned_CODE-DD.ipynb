# %%
import pandas as pd
import scipy.stats  as stats

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/DD-CC-Churned_Code/Coverage-Statement_Branch-COV-DD%20-%20COV-DD.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
is_true = df['Project_Name']=='IO'
df = df[is_true]
df.head()
df['DD'] =  ((df['bugs'] / df['LOC'] )) * 1000
df['Relative_Churned'] =  ((df['Churned_Code'] / df['LOC'] ))

# %%
df.head(25)
# Out:
#    Project_Name Version  commit id  bugs  Statement_Coverage  Branch_Coverage  \
# 10           IO      2.2   5d4d099     6               89.09            81.80
# 11           IO      2.3   c07589b    10               88.99            81.80
# 12           IO      2.4   e36d531    64               89.22            82.02
# 13           IO      2.5   c5ef333    24               88.65            80.85
# 14           IO      2.6   2ae025f    19               89.07            81.48
#
#       LOC  Churned_Code        DD  Relative_Churned
# 10  27419          3439  0.218826          0.125424
# 11  27701           563  0.360998          0.020324
# 12  28207           754  2.268940          0.026731
# 13  33546         11986  0.715436          0.357300
# 14  33764          3273  0.562730          0.096938

# %%
boxplot = df.boxplot(column=['bugs'])

# %%
boxplot = df.boxplot(column=['Relative_Churned'])

# %%
boxplot = df.boxplot(column=['DD'])

# %%
df.plot(x='Relative_Churned', y='DD', style='o')

# %%
df.corr(method ='spearman')
# Out:
#                         bugs  Statement_Coverage  Branch_Coverage       LOC  \
# bugs                1.000000            0.100000         0.051299  0.600000
# Statement_Coverage  0.100000            1.000000         0.820783 -0.300000
# Branch_Coverage     0.051299            0.820783         1.000000 -0.564288
# LOC                 0.600000           -0.300000        -0.564288  1.000000
# Churned_Code        0.000000           -0.300000        -0.666886  0.200000
# DD                  1.000000            0.100000         0.051299  0.600000
# Relative_Churned    0.000000           -0.300000        -0.666886  0.200000
#
#                     Churned_Code        DD  Relative_Churned
# bugs                    0.000000  1.000000          0.000000
# Statement_Coverage     -0.300000  0.100000         -0.300000
# Branch_Coverage        -0.666886  0.051299         -0.666886
# LOC                     0.200000  0.600000          0.200000
# Churned_Code            1.000000  0.000000          1.000000
# DD                      0.000000  1.000000          0.000000
# Relative_Churned        1.000000  0.000000          1.000000

# %%
df[['Relative_Churned','DD']].corr(method ='spearman')
# Out:
#                   Relative_Churned   DD
# Relative_Churned               1.0  0.0
# DD                             0.0  1.0

# %%
#df.to_csv('data.csv')
#from google.colab import files
#files.download("data.csv")

# %%
df.plot(x='Statement_Coverage', y='DD', style='o')

# %%
df_clean = df.dropna()
stats.spearmanr(df_clean['Statement_Coverage'], df_clean['DD'])
# Out:
# SpearmanrResult(correlation=0.09999999999999999, pvalue=0.8728885715695383)

# %%
df[['Statement_Coverage','DD']].corr(method ='spearman')
# Out:
#                     Statement_Coverage   DD
# Statement_Coverage                 1.0  0.1
# DD                                 0.1  1.0

# %%
df.plot(x='Branch_Coverage', y='DD', style='o')

# %%
df_clean = df.dropna()
stats.spearmanr(df_clean['Branch_Coverage'], df_clean['DD'])
# Out:
# SpearmanrResult(correlation=0.05129891760425771, pvalue=0.934712848108234)

# %%
df[['Branch_Coverage','DD']].corr(method ='spearman')
# Out:
#                  Branch_Coverage        DD
# Branch_Coverage         1.000000  0.051299
# DD                      0.051299  1.000000
