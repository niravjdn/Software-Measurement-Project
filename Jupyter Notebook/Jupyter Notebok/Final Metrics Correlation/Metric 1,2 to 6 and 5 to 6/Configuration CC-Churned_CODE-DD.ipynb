# %%
import pandas as pd
import scipy.stats  as stats

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/DD-CC-Churned_Code/Coverage-Statement_Branch-COV-DD%20-%20COV-DD.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
is_true = df['Project_Name']=='Configuration'
df = df[is_true]
df.head()
df['DD'] =  ((df['bugs'] / df['LOC'] )) * 1000
df['Relative_Churned'] =  ((df['Churned_Code'] / df['LOC'] ))

# %%
df.head(25)
# Out:
#     Project_Name Version  commit id  bugs  Statement_Coverage  \
# 5  Configuration      2.1   e814fe0    12               84.72
# 6  Configuration    2.1.1   31c1ab6     6               89.23
# 7  Configuration      2.2   1379979     8               88.40
# 8  Configuration      2.3   43bd7dc     7               89.01
# 9  Configuration      2.4   6543cb0     3               89.05
#
#    Branch_Coverage    LOC  Churned_Code        DD  Relative_Churned
# 5           73.040  85883           754  0.139725          0.008779
# 6           83.266  86541           819  0.069331          0.009464
# 7           83.260  87497          1729  0.091432          0.019761
# 8           83.290  88040           979  0.079509          0.011120
# 9           82.720  88375          9677  0.033946          0.109499

# %%
boxplot = df.boxplot(column=['bugs'])

# %%
boxplot = df.boxplot(column=['Relative_Churned'])

# %%
boxplot = df.boxplot(column=['DD'])

# %%
df.plot(x='Relative_Churned', y='DD', style='o')

# %%
df.corr(method ='spearman')
# Out:
#                     bugs  Statement_Coverage  Branch_Coverage  LOC  \
# bugs                 1.0                -0.9             -0.3 -0.7
# Statement_Coverage  -0.9                 1.0              0.5  0.4
# Branch_Coverage     -0.3                 0.5              1.0  0.3
# LOC                 -0.7                 0.4              0.3  1.0
# Churned_Code        -0.6                 0.3              0.1  0.9
# DD                   1.0                -0.9             -0.3 -0.7
# Relative_Churned    -0.6                 0.3              0.1  0.9
#
#                     Churned_Code   DD  Relative_Churned
# bugs                        -0.6  1.0              -0.6
# Statement_Coverage           0.3 -0.9               0.3
# Branch_Coverage              0.1 -0.3               0.1
# LOC                          0.9 -0.7               0.9
# Churned_Code                 1.0 -0.6               1.0
# DD                          -0.6  1.0              -0.6
# Relative_Churned             1.0 -0.6               1.0

# %%
df[['Relative_Churned','DD']].corr(method ='spearman')
# Out:
#                   Relative_Churned   DD
# Relative_Churned               1.0 -0.6
# DD                            -0.6  1.0

# %%
#df.to_csv('data.csv')
#from google.colab import files
#files.download("data.csv")

# %%
df.plot(x='Statement_Coverage', y='DD', style='o')

# %%
df_clean = df.dropna()
stats.spearmanr(df_clean['Statement_Coverage'], df_clean['DD'])
# Out:
# SpearmanrResult(correlation=-0.8999999999999998, pvalue=0.03738607346849874)

# %%
df[['Statement_Coverage','DD']].corr(method ='spearman')
# Out:
#                     Statement_Coverage   DD
# Statement_Coverage                 1.0 -0.9
# DD                                -0.9  1.0

# %%
df.plot(x='Branch_Coverage', y='DD', style='o')

# %%
df_clean = df.dropna()
stats.spearmanr(df_clean['Branch_Coverage'], df_clean['DD'])
# Out:
# SpearmanrResult(correlation=-0.3, pvalue=0.6238376647810728)

# %%
df[['Branch_Coverage','DD']].corr(method ='spearman')
# Out:
#                  Branch_Coverage   DD
# Branch_Coverage              1.0 -0.3
# DD                          -0.3  1.0
