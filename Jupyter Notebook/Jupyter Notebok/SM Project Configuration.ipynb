# %%
import pandas as pd

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoco/config/jacoco/jacoco.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                           GROUP                                      PACKAGE  \
# 0  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 1  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 2  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 3  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
# 4  Apache Commons Configuration  org.apache.commons.configuration2.beanutils
#
#                                 CLASS  INSTRUCTION_MISSED  \
# 0              ConfigurationDynaClass                  36
# 1                  DefaultBeanFactory                   7
# 2  BeanHelper.BeanCreationContextImpl                   5
# 3         XMLBeanDeclaration.NodeData                   0
# 4                  XMLBeanDeclaration                  51
#
#    INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  \
# 0                  140              4              26            5
# 1                  257              3              27            0
# 2                   30              0               0            1
# 3                   89              0               2            0
# 4                  315              8              28           13
#
#    LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# 0            42                  6                  15              2
# 1            66                  3                  28              0
# 2            11                  1                   5              1
# 3            17                  0                  10              0
# 4            74                  7                  36              0
#
#    METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0               4             89.361702          86.666667  21
# 1              16            100.000000          90.000000  31
# 2               5             91.666667                NaN   6
# 3               9            100.000000         100.000000  10
# 4              25             85.057471          77.777778  43

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.432204       0.751179
# INSTRUCTION_COVERED             0.432204             1.000000       0.557123
# BRANCH_MISSED                   0.751179             0.557123       1.000000
# BRANCH_COVERED                  0.444583             0.887862       0.611334
# LINE_MISSED                     0.878323             0.404407       0.643472
# LINE_COVERED                    0.409517             0.965564       0.534909
# COMPLEXITY_MISSED               0.899243             0.448946       0.863222
# COMPLEXITY_COVERED              0.355675             0.923838       0.471768
# METHOD_MISSED                   0.626914             0.046667       0.282372
# METHOD_COVERED                  0.331777             0.844075       0.389782
# Statement_Percentage           -0.840260            -0.269970      -0.555652
# Branch_Percentage              -0.761309            -0.207849      -0.936306
# CC                              0.534778             0.914142       0.620162
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.444583     0.878323      0.409517
# INSTRUCTION_COVERED         0.887862     0.404407      0.965564
# BRANCH_MISSED               0.611334     0.643472      0.534909
# BRANCH_COVERED              1.000000     0.446111      0.892781
# LINE_MISSED                 0.446111     1.000000      0.432972
# LINE_COVERED                0.892781     0.432972      1.000000
# COMPLEXITY_MISSED           0.487924     0.798622      0.426105
# COMPLEXITY_COVERED          0.887033     0.399891      0.962132
# METHOD_MISSED               0.055644     0.661547      0.048621
# METHOD_COVERED              0.726759     0.381939      0.896135
# Statement_Percentage       -0.328573    -0.971722     -0.302743
# Branch_Percentage          -0.197023    -0.597652     -0.168902
# CC                          0.888849     0.538270      0.937572
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.899243            0.355675       0.626914
# INSTRUCTION_COVERED            0.448946            0.923838       0.046667
# BRANCH_MISSED                  0.863222            0.471768       0.282372
# BRANCH_COVERED                 0.487924            0.887033       0.055644
# LINE_MISSED                    0.798622            0.399891       0.661547
# LINE_COVERED                   0.426105            0.962132       0.048621
# COMPLEXITY_MISSED              1.000000            0.379280       0.636514
# COMPLEXITY_COVERED             0.379280            1.000000       0.041236
# METHOD_MISSED                  0.636514            0.041236       1.000000
# METHOD_COVERED                 0.328612            0.944691       0.047494
# Statement_Percentage          -0.769724           -0.277560      -0.723036
# Branch_Percentage             -0.872677           -0.061765      -0.404084
# CC                             0.563056            0.953174       0.204864
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.331777             -0.840260          -0.761309
# INSTRUCTION_COVERED         0.844075             -0.269970          -0.207849
# BRANCH_MISSED               0.389782             -0.555652          -0.936306
# BRANCH_COVERED              0.726759             -0.328573          -0.197023
# LINE_MISSED                 0.381939             -0.971722          -0.597652
# LINE_COVERED                0.896135             -0.302743          -0.168902
# COMPLEXITY_MISSED           0.328612             -0.769724          -0.872677
# COMPLEXITY_COVERED          0.944691             -0.277560          -0.061765
# METHOD_MISSED               0.047494             -0.723036          -0.404084
# METHOD_COVERED              1.000000             -0.265480          -0.037454
# Statement_Percentage       -0.265480              1.000000           0.599204
# Branch_Percentage          -0.037454              0.599204           1.000000
# CC                          0.895749             -0.428551          -0.290803
#
#                             CC
# INSTRUCTION_MISSED    0.534778
# INSTRUCTION_COVERED   0.914142
# BRANCH_MISSED         0.620162
# BRANCH_COVERED        0.888849
# LINE_MISSED           0.538270
# LINE_COVERED          0.937572
# COMPLEXITY_MISSED     0.563056
# COMPLEXITY_COVERED    0.953174
# METHOD_MISSED         0.204864
# METHOD_COVERED        0.895749
# Statement_Percentage -0.428551
# Branch_Percentage    -0.290803
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.428551
# Statement_Percentage -0.428551              1.000000

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.290803
# Branch_Percentage -0.290803           1.000000

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 89.05625053186964

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 82.72532188841201
