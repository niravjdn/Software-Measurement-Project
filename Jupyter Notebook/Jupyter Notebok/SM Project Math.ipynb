# %%
import pandas as pd

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoco/math/jacoco/jacoco.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                  GROUP                                            PACKAGE  \
# 0  Apache Commons Math  org.apache.commons.math3.optim.nonlinear.scala...
# 1  Apache Commons Math  org.apache.commons.math3.optim.nonlinear.scala...
# 2  Apache Commons Math  org.apache.commons.math3.optim.nonlinear.scala...
# 3  Apache Commons Math  org.apache.commons.math3.optim.nonlinear.scala...
# 4  Apache Commons Math  org.apache.commons.math3.optim.nonlinear.scala...
#
#                                                CLASS  INSTRUCTION_MISSED  \
# 0  NonLinearConjugateGradientOptimizer.IdentityPr...                   0
# 1        NonLinearConjugateGradientOptimizer.Formula                   5
# 2  NonLinearConjugateGradientOptimizer.new Object...                   2
# 3                NonLinearConjugateGradientOptimizer                  30
# 4  NonLinearConjugateGradientOptimizer.Bracketing...                   9
#
#    INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  \
# 0                    7              0               0            0
# 1                   33              0               0            0
# 2                   17              0               0            0
# 3                  297              5              28           10
# 4                    0              0               0            4
#
#    LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# 0             2                  0                   2              0
# 1             3                  1                   3              1
# 2             1                  0                   1              0
# 3            61                  7                  19              2
# 4             0                  2                   0              2
#
#    METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0               2            100.000000                NaN   2
# 1               3            100.000000                NaN   4
# 2               1            100.000000                NaN   1
# 3               7             85.915493          84.848485  26
# 4               0              0.000000                NaN   2

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.371323       0.726187
# INSTRUCTION_COVERED             0.371323             1.000000       0.568177
# BRANCH_MISSED                   0.726187             0.568177       1.000000
# BRANCH_COVERED                  0.447532             0.883841       0.676440
# LINE_MISSED                     0.934476             0.373623       0.719070
# LINE_COVERED                    0.387058             0.958237       0.597044
# COMPLEXITY_MISSED               0.913545             0.470458       0.838321
# COMPLEXITY_COVERED              0.379985             0.909115       0.562694
# METHOD_MISSED                   0.737578             0.122098       0.322555
# METHOD_COVERED                  0.344194             0.797143       0.480163
# Statement_Percentage           -0.796668            -0.020763      -0.460054
# Branch_Percentage              -0.620075             0.074478      -0.765969
# CC                              0.603300             0.842708       0.719633
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.447532     0.934476      0.387058
# INSTRUCTION_COVERED         0.883841     0.373623      0.958237
# BRANCH_MISSED               0.676440     0.719070      0.597044
# BRANCH_COVERED              1.000000     0.485960      0.899782
# LINE_MISSED                 0.485960     1.000000      0.435194
# LINE_COVERED                0.899782     0.435194      1.000000
# COMPLEXITY_MISSED           0.563971     0.899834      0.503875
# COMPLEXITY_COVERED          0.899187     0.427359      0.950994
# METHOD_MISSED               0.158417     0.745511      0.147454
# METHOD_COVERED              0.715162     0.388953      0.855361
# Statement_Percentage       -0.163970    -0.869375     -0.089859
# Branch_Percentage           0.084143    -0.569599      0.045382
# CC                          0.878437     0.641760      0.890355
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.913545            0.379985       0.737578
# INSTRUCTION_COVERED            0.470458            0.909115       0.122098
# BRANCH_MISSED                  0.838321            0.562694       0.322555
# BRANCH_COVERED                 0.563971            0.899187       0.158417
# LINE_MISSED                    0.899834            0.427359       0.745511
# LINE_COVERED                   0.503875            0.950994       0.147454
# COMPLEXITY_MISSED              1.000000            0.491817       0.706769
# COMPLEXITY_COVERED             0.491817            1.000000       0.175504
# METHOD_MISSED                  0.706769            0.175504       1.000000
# METHOD_COVERED                 0.442770            0.921236       0.210110
# Statement_Percentage          -0.737142           -0.090580      -0.736750
# Branch_Percentage             -0.668531            0.101830      -0.309017
# CC                             0.718505            0.921009       0.385764
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.344194             -0.796668          -0.620075
# INSTRUCTION_COVERED         0.797143             -0.020763           0.074478
# BRANCH_MISSED               0.480163             -0.460054          -0.765969
# BRANCH_COVERED              0.715162             -0.163970           0.084143
# LINE_MISSED                 0.388953             -0.869375          -0.569599
# LINE_COVERED                0.855361             -0.089859           0.045382
# COMPLEXITY_MISSED           0.442770             -0.737142          -0.668531
# COMPLEXITY_COVERED          0.921236             -0.090580           0.101830
# METHOD_MISSED               0.210110             -0.736750          -0.309017
# METHOD_COVERED              1.000000             -0.088790          -0.000777
# Statement_Percentage       -0.088790              1.000000           0.658690
# Branch_Percentage          -0.000777              0.658690           1.000000
# CC                          0.839558             -0.336964          -0.126399
#
#                             CC
# INSTRUCTION_MISSED    0.603300
# INSTRUCTION_COVERED   0.842708
# BRANCH_MISSED         0.719633
# BRANCH_COVERED        0.878437
# LINE_MISSED           0.641760
# LINE_COVERED          0.890355
# COMPLEXITY_MISSED     0.718505
# COMPLEXITY_COVERED    0.921009
# METHOD_MISSED         0.385764
# METHOD_COVERED        0.839558
# Statement_Percentage -0.336964
# Branch_Percentage    -0.126399
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.336964
# Statement_Percentage -0.336964              1.000000

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.126399
# Branch_Percentage -0.126399           1.000000

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 89.62684275184274

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 84.86099521278932
