# %%
import pandas as pd

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/pit-jacoco/collection-mu-st-branch.csv', error_bad_lines=False)

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/pit-jacoco/config-mu-st-branch.csv', error_bad_lines=False)

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/pit-jacoco/io-mu-st-branch.csv', error_bad_lines=False)

# %%
df4 = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/pit-jacoco/lang-mu-st-branch.csv', error_bad_lines=False)

# %%
df5 = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/pit-jacoco/math-mu-st-branch.csv', error_bad_lines=False)

# %%
df = pd.concat([df1, df2,df3, df4, df5], ignore_index=True)

# %%
import matplotlib.pyplot as plt

# %%
df.plot(x='Mutation_Score', y='Statement_Percentage', style='o')

# %%
df[['Mutation_Score','Statement_Percentage']].corr(method ='spearman')
# Out:
#                       Mutation_Score  Statement_Percentage
# Mutation_Score              1.000000              0.614612
# Statement_Percentage        0.614612              1.000000

# %%
df.plot(x='Mutation_Score', y='Branch_Percentage', style='o')

# %%
df[['Mutation_Score','Branch_Percentage']].corr(method ='spearman')
# Out:
#                    Mutation_Score  Branch_Percentage
# Mutation_Score           1.000000           0.454481
# Branch_Percentage        0.454481           1.000000
