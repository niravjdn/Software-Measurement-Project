# %%
import pandas as pd

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoco/lang/jacoco/jacoco.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                  GROUP                        PACKAGE  \
# 0  Apache Commons Lang  org.apache.commons.lang3.time
# 1  Apache Commons Lang  org.apache.commons.lang3.time
# 2  Apache Commons Lang  org.apache.commons.lang3.time
# 3  Apache Commons Lang  org.apache.commons.lang3.time
# 4  Apache Commons Lang  org.apache.commons.lang3.time
#
#                                         CLASS  INSTRUCTION_MISSED  \
# 0                   FastDatePrinter.TextField                   0
# 1      FastDateParser.ISO8601TimeZoneStrategy                   0
# 2                        DateUtils.ModifyType                  21
# 3  FastDateParser.CaseInsensitiveTextStrategy                   0
# 4                                 GmtTimeZone                   2
#
#    INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  \
# 0                   43              0               4            0
# 1                   41              0               4            0
# 2                   39              0               0            1
# 3                   71              0               2            0
# 4                  135              1              11            0
#
#    LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# 0            12                  0                   5              0
# 1            13                  0                   7              0
# 2             7                  2                   2              2
# 3            16                  0                   3              0
# 4            23                  1                  16              0
#
#    METHOD_COVERED  Statement_Percentage  Branch_Percentage  CC
# 0               3                 100.0         100.000000   5
# 1               4                 100.0         100.000000   7
# 2               2                  87.5                NaN   4
# 3               2                 100.0         100.000000   3
# 4              11                 100.0          91.666667  17

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.458409       0.640804
# INSTRUCTION_COVERED             0.458409             1.000000       0.631297
# BRANCH_MISSED                   0.640804             0.631297       1.000000
# BRANCH_COVERED                  0.397516             0.824703       0.695335
# LINE_MISSED                     0.947268             0.425099       0.628177
# LINE_COVERED                    0.429656             0.954723       0.624856
# COMPLEXITY_MISSED               0.861275             0.548705       0.842980
# COMPLEXITY_COVERED              0.329165             0.916801       0.585618
# METHOD_MISSED                   0.762707             0.235692       0.304620
# METHOD_COVERED                  0.323449             0.835301       0.490437
# Statement_Percentage           -0.868639            -0.186556      -0.421282
# Branch_Percentage              -0.639178            -0.322897      -0.873938
# CC                              0.458551             0.937979       0.653061
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.397516     0.947268      0.429656
# INSTRUCTION_COVERED         0.824703     0.425099      0.954723
# BRANCH_MISSED               0.695335     0.628177      0.624856
# BRANCH_COVERED              1.000000     0.407147      0.823761
# LINE_MISSED                 0.407147     1.000000      0.438584
# LINE_COVERED                0.823761     0.438584      1.000000
# COMPLEXITY_MISSED           0.541694     0.827634      0.516345
# COMPLEXITY_COVERED          0.844245     0.334454      0.939388
# METHOD_MISSED               0.158558     0.746463      0.200233
# METHOD_COVERED              0.636222     0.319728      0.861452
# Statement_Percentage       -0.170572    -0.918383     -0.198175
# Branch_Percentage          -0.322778    -0.588240     -0.299355
# CC                          0.841034     0.446707      0.948141
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.861275            0.329165       0.762707
# INSTRUCTION_COVERED            0.548705            0.916801       0.235692
# BRANCH_MISSED                  0.842980            0.585618       0.304620
# BRANCH_COVERED                 0.541694            0.844245       0.158558
# LINE_MISSED                    0.827634            0.334454       0.746463
# LINE_COVERED                   0.516345            0.939388       0.200233
# COMPLEXITY_MISSED              1.000000            0.438511       0.677646
# COMPLEXITY_COVERED             0.438511            1.000000       0.137449
# METHOD_MISSED                  0.677646            0.137449       1.000000
# METHOD_COVERED                 0.368015            0.922318       0.155681
# Statement_Percentage          -0.728523           -0.063381      -0.749760
# Branch_Percentage             -0.805946           -0.210044      -0.310958
# CC                             0.568983            0.975342       0.253463
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.323449             -0.868639          -0.639178
# INSTRUCTION_COVERED         0.835301             -0.186556          -0.322897
# BRANCH_MISSED               0.490437             -0.421282          -0.873938
# BRANCH_COVERED              0.636222             -0.170572          -0.322778
# LINE_MISSED                 0.319728             -0.918383          -0.588240
# LINE_COVERED                0.861452             -0.198175          -0.299355
# COMPLEXITY_MISSED           0.368015             -0.728523          -0.805946
# COMPLEXITY_COVERED          0.922318             -0.063381          -0.210044
# METHOD_MISSED               0.155681             -0.749760          -0.310958
# METHOD_COVERED              1.000000             -0.060651          -0.197818
# Statement_Percentage       -0.060651              1.000000           0.565962
# Branch_Percentage          -0.197818              0.565962           1.000000
# CC                          0.903616             -0.206430          -0.335135
#
#                             CC
# INSTRUCTION_MISSED    0.458551
# INSTRUCTION_COVERED   0.937979
# BRANCH_MISSED         0.653061
# BRANCH_COVERED        0.841034
# LINE_MISSED           0.446707
# LINE_COVERED          0.948141
# COMPLEXITY_MISSED     0.568983
# COMPLEXITY_COVERED    0.975342
# METHOD_MISSED         0.253463
# METHOD_COVERED        0.903616
# Statement_Percentage -0.206430
# Branch_Percentage    -0.335135
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                            CC  Statement_Percentage
# CC                    1.00000              -0.20643
# Statement_Percentage -0.20643               1.00000

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.335135
# Branch_Percentage -0.335135           1.000000

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 95.20958083832335

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 91.03551775887944
