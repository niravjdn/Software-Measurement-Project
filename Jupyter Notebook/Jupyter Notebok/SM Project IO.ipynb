# %%
import pandas as pd

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoco/io/jacoco/jacoco.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                GROUP                           PACKAGE  \
# 0  Apache Commons IO  org.apache.commons.io.comparator
# 1  Apache Commons IO  org.apache.commons.io.comparator
# 2  Apache Commons IO  org.apache.commons.io.comparator
# 3  Apache Commons IO  org.apache.commons.io.comparator
# 4  Apache Commons IO  org.apache.commons.io.comparator
#
#                         CLASS  INSTRUCTION_MISSED  INSTRUCTION_COVERED  \
# 0     ExtensionFileComparator                   0                   75
# 1           ReverseComparator                   5                   30
# 2          SizeFileComparator                   0                  105
# 3          NameFileComparator                   0                   69
# 4  LastModifiedFileComparator                   0                   33
#
#    BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# 0              0               2            0            18
# 1              1               1            1             6
# 2              2              14            0            27
# 3              0               2            0            14
# 4              0               4            0             9
#
#    COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  METHOD_COVERED  \
# 0                  0                   6              0               5
# 1                  1                   3              0               3
# 2                  2                  11              0               5
# 3                  0                   6              0               5
# 4                  0                   5              0               3
#
#    Statement_Percentage  Branch_Percentage  CC
# 0            100.000000              100.0   6
# 1             85.714286               50.0   4
# 2            100.000000               87.5  13
# 3            100.000000              100.0   6
# 4            100.000000              100.0   5

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.445618       0.693465
# INSTRUCTION_COVERED             0.445618             1.000000       0.519332
# BRANCH_MISSED                   0.693465             0.519332       1.000000
# BRANCH_COVERED                  0.459544             0.927791       0.566666
# LINE_MISSED                     0.956386             0.351174       0.580819
# LINE_COVERED                    0.474650             0.970652       0.517876
# COMPLEXITY_MISSED               0.866966             0.465691       0.852089
# COMPLEXITY_COVERED              0.430528             0.944155       0.478262
# METHOD_MISSED                   0.803034             0.241925       0.460738
# METHOD_COVERED                  0.437957             0.846329       0.444697
# Statement_Percentage           -0.869512            -0.110367      -0.416251
# Branch_Percentage              -0.655848            -0.125720      -0.914626
# CC                              0.666230             0.855169       0.678477
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.459544     0.956386      0.474650
# INSTRUCTION_COVERED         0.927791     0.351174      0.970652
# BRANCH_MISSED               0.566666     0.580819      0.517876
# BRANCH_COVERED              1.000000     0.365140      0.904295
# LINE_MISSED                 0.365140     1.000000      0.384698
# LINE_COVERED                0.904295     0.384698      1.000000
# COMPLEXITY_MISSED           0.520319     0.795433      0.482719
# COMPLEXITY_COVERED          0.902907     0.339913      0.962605
# METHOD_MISSED               0.278456     0.848791      0.270265
# METHOD_COVERED              0.731947     0.360144      0.891007
# Statement_Percentage       -0.137594    -0.929246     -0.139657
# Branch_Percentage          -0.123990    -0.560208     -0.146582
# CC                          0.847913     0.587874      0.875965
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.866966            0.430528       0.803034
# INSTRUCTION_COVERED            0.465691            0.944155       0.241925
# BRANCH_MISSED                  0.852089            0.478262       0.460738
# BRANCH_COVERED                 0.520319            0.902907       0.278456
# LINE_MISSED                    0.795433            0.339913       0.848791
# LINE_COVERED                   0.482719            0.962605       0.270265
# COMPLEXITY_MISSED              1.000000            0.450153       0.789524
# COMPLEXITY_COVERED             0.450153            1.000000       0.246361
# METHOD_MISSED                  0.789524            0.246361       1.000000
# METHOD_COVERED                 0.424029            0.939302       0.250494
# Statement_Percentage          -0.692730           -0.099002      -0.804655
# Branch_Percentage             -0.820684           -0.097114      -0.467866
# CC                             0.705324            0.893435       0.506162
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.437957             -0.869512          -0.655848
# INSTRUCTION_COVERED         0.846329             -0.110367          -0.125720
# BRANCH_MISSED               0.444697             -0.416251          -0.914626
# BRANCH_COVERED              0.731947             -0.137594          -0.123990
# LINE_MISSED                 0.360144             -0.929246          -0.560208
# LINE_COVERED                0.891007             -0.139657          -0.146582
# COMPLEXITY_MISSED           0.424029             -0.692730          -0.820684
# COMPLEXITY_COVERED          0.939302             -0.099002          -0.097114
# METHOD_MISSED               0.250494             -0.804655          -0.467866
# METHOD_COVERED              1.000000             -0.133919          -0.144273
# Statement_Percentage       -0.133919              1.000000           0.545775
# Branch_Percentage          -0.144273              0.545775           1.000000
# CC                          0.840800             -0.367882          -0.403387
#
#                             CC
# INSTRUCTION_MISSED    0.666230
# INSTRUCTION_COVERED   0.855169
# BRANCH_MISSED         0.678477
# BRANCH_COVERED        0.847913
# LINE_MISSED           0.587874
# LINE_COVERED          0.875965
# COMPLEXITY_MISSED     0.705324
# COMPLEXITY_COVERED    0.893435
# METHOD_MISSED         0.506162
# METHOD_COVERED        0.840800
# Statement_Percentage -0.367882
# Branch_Percentage    -0.403387
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                             CC  Statement_Percentage
# CC                    1.000000             -0.367882
# Statement_Percentage -0.367882              1.000000

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.403387
# Branch_Percentage -0.403387           1.000000

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 87.9508970727101

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 78.73107426099494

# %%
df_collection.BRANCH_COVERED.sum() + df_collection.BRANCH_MISSED.sum()
# Out:
# 2774
