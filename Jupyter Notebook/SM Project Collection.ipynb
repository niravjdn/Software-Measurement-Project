# %%
import pandas as pd

# %%
df_collection = pd.read_csv('https://raw.githubusercontent.com/niravjdn/Software-Measurement-Project/master/data/jacoco/collection/jacoco/jacoco.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['Statement_Percentage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['Branch_Percentage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CC'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.head()
# Out:
#                         GROUP                                   PACKAGE  \
# 0  Apache Commons Collections  org.apache.commons.collections4.keyvalue
# 1  Apache Commons Collections  org.apache.commons.collections4.keyvalue
# 2  Apache Commons Collections  org.apache.commons.collections4.keyvalue
# 3  Apache Commons Collections  org.apache.commons.collections4.keyvalue
# 4  Apache Commons Collections  org.apache.commons.collections4.keyvalue
#
#                   CLASS  INSTRUCTION_MISSED  INSTRUCTION_COVERED  \
# 0          TiedMapEntry                   3                  106
# 1      AbstractMapEntry                   0                   70
# 2  UnmodifiableMapEntry                   0                   24
# 3      AbstractKeyValue                   0                   44
# 4              MultiKey                   0                  195
#
#    BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# 0              5              17            1            21
# 1              1              19            0            13
# 2              0               0            0             7
# 3              0               0            0            17
# 4              0              12            0            37
#
#    COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  METHOD_COVERED  \
# 0                  5                  13              0               7
# 1                  1                  13              0               4
# 2                  0                   4              0               4
# 3                  0                   6              0               6
# 4                  0                  20              0              14
#
#    Statement_Percentage  Branch_Percentage  CC
# 0             95.454545          77.272727  18
# 1            100.000000          95.000000  14
# 2            100.000000                NaN   4
# 3            100.000000                NaN   6
# 4            100.000000         100.000000  20

# %%
df_collection.loc[df_collection['CLASS'].isin(['ArrayUtils'])]
# Out:
#                           GROUP                          PACKAGE       CLASS  \
# 411  Apache Commons Collections  org.apache.commons.collections4  ArrayUtils
#
#      INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  \
# 411                  22                   38              7               9
#
#      LINE_MISSED  LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  \
# 411            6             9                  6                   6
#
#      METHOD_MISSED  METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# 411              1               3                  60.0              56.25
#
#      CC
# 411  12

# %%
df_collection.plot(x='CC', y='Statement_Percentage', style='o')

# %%
df_collection.plot(x='CC', y='Branch_Percentage', style='o')

# %%
plt.scatter(df_collection['CC'], df_collection['Statement_Percentage'])
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_collection.corr(method ='spearman')
# Out:
#                       INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED              1.000000             0.420565       0.700509
# INSTRUCTION_COVERED             0.420565             1.000000       0.539084
# BRANCH_MISSED                   0.700509             0.539084       1.000000
# BRANCH_COVERED                  0.425422             0.867807       0.597209
# LINE_MISSED                     0.977211             0.401334       0.658774
# LINE_COVERED                    0.437437             0.964688       0.524910
# COMPLEXITY_MISSED               0.948946             0.485747       0.788469
# COMPLEXITY_COVERED              0.410654             0.936534       0.482974
# METHOD_MISSED                   0.804959             0.168751       0.321390
# METHOD_COVERED                  0.383447             0.839320       0.406753
# Statement_Percentage           -0.896230            -0.156121      -0.498953
# Branch_Percentage              -0.648662            -0.096706      -0.880122
# CC                              0.625607             0.892976       0.635256
#
#                       BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED          0.425422     0.977211      0.437437
# INSTRUCTION_COVERED         0.867807     0.401334      0.964688
# BRANCH_MISSED               0.597209     0.658774      0.524910
# BRANCH_COVERED              1.000000     0.403468      0.847872
# LINE_MISSED                 0.403468     1.000000      0.431060
# LINE_COVERED                0.847872     0.431060      1.000000
# COMPLEXITY_MISSED           0.506724     0.938025      0.497879
# COMPLEXITY_COVERED          0.828769     0.404462      0.945417
# METHOD_MISSED               0.152335     0.835166      0.203296
# METHOD_COVERED              0.635569     0.383507      0.864056
# Statement_Percentage       -0.190060    -0.923281     -0.188457
# Branch_Percentage          -0.094221    -0.606332     -0.084521
# CC                          0.809227     0.618079      0.905757
#
#                       COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED             0.948946            0.410654       0.804959
# INSTRUCTION_COVERED            0.485747            0.936534       0.168751
# BRANCH_MISSED                  0.788469            0.482974       0.321390
# BRANCH_COVERED                 0.506724            0.828769       0.152335
# LINE_MISSED                    0.938025            0.404462       0.835166
# LINE_COVERED                   0.497879            0.945417       0.203296
# COMPLEXITY_MISSED              1.000000            0.484240       0.759479
# COMPLEXITY_COVERED             0.484240            1.000000       0.216997
# METHOD_MISSED                  0.759479            0.216997       1.000000
# METHOD_COVERED                 0.445169            0.942134       0.238598
# Statement_Percentage          -0.843606           -0.172496      -0.848922
# Branch_Percentage             -0.716107           -0.028772      -0.310312
# CC                             0.698162            0.945566       0.418478
#
#                       METHOD_COVERED  Statement_Percentage  Branch_Percentage  \
# INSTRUCTION_MISSED          0.383447             -0.896230          -0.648662
# INSTRUCTION_COVERED         0.839320             -0.156121          -0.096706
# BRANCH_MISSED               0.406753             -0.498953          -0.880122
# BRANCH_COVERED              0.635569             -0.190060          -0.094221
# LINE_MISSED                 0.383507             -0.923281          -0.606332
# LINE_COVERED                0.864056             -0.188457          -0.084521
# COMPLEXITY_MISSED           0.445169             -0.843606          -0.716107
# COMPLEXITY_COVERED          0.942134             -0.172496          -0.028772
# METHOD_MISSED               0.238598             -0.848922          -0.310312
# METHOD_COVERED              1.000000             -0.168402          -0.052852
# Statement_Percentage       -0.168402              1.000000           0.600995
# Branch_Percentage          -0.052852              0.600995           1.000000
# CC                          0.888442             -0.410830          -0.272829
#
#                             CC
# INSTRUCTION_MISSED    0.625607
# INSTRUCTION_COVERED   0.892976
# BRANCH_MISSED         0.635256
# BRANCH_COVERED        0.809227
# LINE_MISSED           0.618079
# LINE_COVERED          0.905757
# COMPLEXITY_MISSED     0.698162
# COMPLEXITY_COVERED    0.945566
# METHOD_MISSED         0.418478
# METHOD_COVERED        0.888442
# Statement_Percentage -0.410830
# Branch_Percentage    -0.272829
# CC                    1.000000

# %%
df_collection[['CC','Statement_Percentage']].corr(method ='spearman')
# Out:
#                            CC  Statement_Percentage
# CC                    1.00000              -0.41083
# Statement_Percentage -0.41083               1.00000

# %%
df_collection[['CC','Branch_Percentage']].corr(method ='spearman')
# Out:
#                          CC  Branch_Percentage
# CC                 1.000000          -0.272829
# Branch_Percentage -0.272829           1.000000

# %%
print('Total Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Total Statment Coverage 87.8011354917907

# %%
print('Total Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Total Branch Coverage 81.30200685266765
